# %% [markdown]
# ## Data Smells
#
# Any time you are given a dataset from anyone, you should immediately be suspicious. Is this data what I think it is? Does it include what I expect? Is there anything I need to know about it? Will it produce the information I expect?
#
# One of the first things you should do is give it the smell test.
#
# Failure to give data the smell test [can lead you to miss stories and get your butt kicked on a competitive story](https://source.opennews.org/en-US/learning/handling-data-about-race-and-ethnicity/).
#
# Let's look at arrest data for Fairfax County, Va. You can find the `arrest.csv` file in this repository.

# %%
import agate
arrests = agate.Table.from_csv('arrest.csv')

# %% [markdown]
# With data smells, we're trying to find common mistakes in data. For more on data smells, read the GitHub wiki post that started it all. The common mistakes we're looking for are:
#
# * Missing data
# * Gaps in data
# * Wrong type of data
# * Outliers
# * Sharp curves
# * Conflicting information within a dataset
# * Conflicting information across datasets
# * Wrongly derived data
# * External inconsistency
# * Wrong spatial data
# * Unusuable data, including non-standard abbreviations, ambigious data, extraneous data, inconsistent data
#
# Not all of these data smells are detectable in code. You may have to ask people about the data. You may have to compare it to another dataset yourself. Does the agency that uses the data produce reports from the data? Does your analysis match those reports? That will expose wrongly derived data, or wrong units, or mistakes you made with inclusion or exclusion.
#
# But with several of these data smells, we can do them first, before we do anything else. First, let's look at **Wrong Type Of Data**. We can sniff that out by simply printing the table structure that Agate has discovered for us.

# %%
print arrests
# Out:
# |-----------------+---------------|
# |  column_names   | column_types  |
# |-----------------+---------------|
# |  LName          | Text          |
# |  FName          | Text          |
# |  MName          | Text          |
# |  Age            | Number        |
# |  DateArr        | Date          |
# |  Charge         | Text          |
# |  Charge Descrip | Text          |
# |  Address        | Text          |
# |-----------------+---------------|

# %% [markdown]
# Things seem to look good for this file. The name columns are text, the age column is a number, the date is a date, etc.
#
# The second smell we can find in Agate is Missing Data. We can do that through a series of Group By and Count steps. Let's start with Charge Descrip.

# %%
ages = arrests.group_by('Charge Descrip')
charge_counts = charges.aggregate([('charge_total', agate.Count('Charge Descrip'))])
charge_counts = charge_counts.order_by('charge_total', reverse=True)

# %%
charge_counts.print_table(max_column_width=50)
# Out:
# |-----------------------------------------------------+---------------|
# |  Charge Descrip                                     | charge_total  |
# |-----------------------------------------------------+---------------|
# |  LICENSE: DRIVE W/O                                 |          397  |
# |  LIC REVOKED: DR W/O LICENSE, 1 OFF                 |          385  |
# |  DRUNK IN PUBLIC OR PROFANE                         |          177  |
# |  DRUGS: POSSESS MARIJUANA, 1ST OFF                  |          161  |
# |  PETIT LARCENY: <$200 NOT FROM A PERSON             |           98  |
# |  ASSAULT: ON FAMILY MEMBER                          |           96  |
# |  RECKLE/20 MPH OVER LIMIT                           |           92  |
# |  GRAND LARCENY: $200+ NOT FROM A PERSON             |           88  |
# |  DRUGS: POSSESS SCH I OR II                         |           61  |
# |  RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY    |           59  |
# |  LIC REVOKED: DR W/O LICENSE, 2 OFF                 |           57  |
# |  DWI: 1ST OFFENSE                                   |           57  |
# |  FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE          |           54  |
# |  LICENSE: DRIVE W/O, 2+ OFFENSE                     |           53  |
# |  INSUR: OPERATE UNINSURED VEH                       |           47  |
# |  ASSAULT: (MISDEMEANOR)                             |           43  |
# |  CREDIT CARD LARCENY: TAKE/OBTAIN NO.               |           42  |
# |  RECK DR: SPEEDING 20MPH+                           |           34  |
# |  DRUGS: POSSESS MARIJUANA, 2+ OFF                   |           31  |
# |  TRESPASS-POSTED OR ADVISED TO LV                   |           31  |
# |  DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS      |           30  |
# |  PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE           |           30  |
# |  DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II         |           30  |
# |  POSS OPEN ALCH CONT                                |           28  |
# |  DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF        |           28  |
# |  TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS    |           28  |
# |  OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200     |           28  |
# |  PROBATION: VIOLATION ON FELONY OFFENSE             |           27  |
# |  SHOPLIFT/ALTER PRICE: LARCENY <$200                |           24  |
# |  DWI: 1ST OFF, BAC .15-.20%                         |           23  |
# |  RECKL/SPEED OVER 80 MPH                            |           22  |
# |  CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS           |           22  |
# |  STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200  |           21  |
# |  DRIVE WHILE REVOKED-DWI                            |           21  |
# |  FAILURE TO APPEAR: ON FELONY OFFENSE               |           20  |
# |  LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH   |           20  |
# |  ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON    |           19  |
# |  MONUMENT: INTENTIONAL DAMAGE, VALUE <$1000         |           18  |
# |  UNLICENSED DOG                                     |           16  |
# |  RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS   |           16  |
# |  EMBEZZLEMENT: >=$200                               |           16  |
# |  CREDIT CARD FRAUD: BY PERSON>=$200 IN 6M           |           16  |
# |  LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS         |           15  |
# |  FALSE IDENTIFY SELF TO LAW ENFORCEMENT             |           15  |
# |  PROTECTIVE ORDER: VIOLATION                        |           15  |
# |  CREDIT CARD FORGERY                                |           15  |
# |  TRESPASS: AFTER BEING FORBIDDEN TO DO SO           |           14  |
# |  STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY    |           14  |
# |  DISORDERLY CONDUCT                                 |           14  |
# |  OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200    |           14  |
# |  LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS    |           13  |
# |  LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 1 OFF   |           13  |
# |  CONTRIBUTE TO DELINQUENCY OF MINOR                 |           13  |
# |  OBSTRUCT JUSTICE: W/O THREATS/FORCE                |           13  |
# |  UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY<200   |           13  |
# |  DRINKING WHILE DRIVING OR OPEN CONTAINER           |           12  |
# |  PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF        |           11  |
# |  ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000      |           11  |
# |  IDENTITY THEFT: POSSESS FICTITIOUS ID CARD         |           11  |
# |  STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200          |           11  |
# |  RECK DR: SPEEDING, OVER 80MPH                      |           11  |
# |  PRESCRIPTIONS: OBTAIN BY FRAUD/FORGERY/ETC         |           11  |
# |  IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.     |           10  |
# |  EMBEZZLEMENT: <$200                                |           10  |
# |  GRAND LARCENY: $5+ FROM A PERSON (PICK POCKET)     |           10  |
# |  CONCEALED WEAPON: CARRY                            |           10  |
# |  BURGLARIOUS TOOLS: POSSESSION OF                   |            9  |
# |  LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR   |            9  |
# |  PROFANE SWEARING OR INTOXICATION IN PUBLIC         |            9  |
# |  PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG     |            9  |
# |  CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M          |            9  |
# |  OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170   |            9  |
# |  DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY    |            9  |
# |  ROBBERY: ON OR NEAR STREET                         |            9  |
# |  TRESPASS SCH FORBIDDEN                             |            9  |
# |  DISREG POLICE SIGNAL TO STOP,EL                    |            8  |
# |  ENTER PROPERTY TO DAMAGE, ETC.:                    |            8  |
# |  BAILEE: VIOLATE CONDITION OF RELEASE               |            8  |
# |  DRUGS: DISTRIB/PWI MARIJUANA <1/2 OZ               |            8  |
# |  LARCENY: THIRD OR SUBSEQUENT CONVICTION            |            8  |
# |  IDENTITY THEFT: OBTAIN ID TO DEFRAUD               |            7  |
# |  DWI: 2ND OFF W/IN 5Y                               |            7  |
# |  RESISTING ARREST                                   |            7  |
# |  PUBLIC RECORDS: FORGERY                            |            7  |
# |  ABDUCTION: BY FORCE, INTIMIDATION OR DECEPTION     |            7  |
# |  MALICIOUS BODILY INJURY                            |            6  |
# |  MALICIOUS WOUNDING                                 |            6  |
# |  UNVACCINATED DOG OR CAT                            |            6  |
# |  DRUGS: POSSESS SCH IV                              |            6  |
# |  DRUGS: POSSESS W/INTENT TO MANUF/SELL SCH I, II    |            6  |
# |  PROBATION VIOLATION-FELONY                         |            6  |
# |  BURGLARY: ENTER BLDG TO COMMIT LARCENY/A&B/ETC     |            6  |
# |  ALCOHOL: PURCH/POSSESS BY PERSON <21Y              |            6  |
# |  PLATES/DECALS: POSSESS/FORGED                      |            6  |
# |  PETIT LARCENY: <$5 FROM A PERSON (PICK POCKET)     |            6  |
# |  EXCESSIVE NOISE IN RESIDENTIAL DWELLING (GENERAL)  |            6  |
# |  DWI: DRUGS, 1ST OFFENSE                            |            6  |
# |  LIC REVOKED: DR W/O LICENSE, 3+ OFF > 10 YRS       |            6  |
# |  DUMPING TRASH, COMP ANIMAL, ETC ON HIWAY, PROPERTY |            6  |
# |  PROPOSE SEX BY COMP  <15 OFFENDR 7+ YR, 2ND OFF    |            6  |
# |  OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF   |            6  |
# |  RECK DR: DR TOO FAST FOR HWY CONDITIONS            |            5  |
# |  OPERATE VEHICLE WITH SUN-SHADING/TINTING FILMS     |            5  |
# |  DRUGS: POSSESS SCH III                             |            5  |
# |  DWI: 2ND OFF W/IN 5Y - 10Y                         |            5  |
# |  DWI: REFUSAL OF BLOOD OR BREATH TEST, 2 OFF        |            5  |
# |  FIREARM/ETC: POINTING/BRANDISHING                  |            5  |
# |  CREDIT CARD FORGERY DEVICES: POSSESS               |            5  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$500   |            5  |
# |  PROSTITUTION                                       |            5  |
# |  ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y     |            5  |
# |  DRUGS: MANUF/DISTRIBUTE ON CERTAIN PROPERTIES      |            5  |
# |  OTHER FORGERY WRITING: EMPLOY AS TRUE              |            5  |
# |  RECK DR: DR OUT OF CONTROL OR BAD BRAKES           |            5  |
# |  PHONE: INJURE/TAP LINE; COPY/OBSTRUCT MESSAGE      |            4  |
# |  RUNNING AT LARGE                                   |            4  |
# |  OBSTRUCT JUSTICE: W/ THREATS/FORCE                 |            4  |
# |  GRAND LARCENY: AUTO THEFT                          |            4  |
# |  PROBATION: VIOLATION ON MISDEMEANOR OFFENSE        |            4  |
# |  MONUMENT: INTENTIONAL DAMAGE, VALUE >=$1000        |            4  |
# |  FORGERY: OBTAIN SIGNATURE BY FALSE PRETENSE        |            4  |
# |  MONUMENT: UNLAWFUL DAMAGE, NO INTENT TO STEAL      |            4  |
# |  RECK DR: GENERALLY + REV LIC & CAUSE DEATH         |            4  |
# |  MASSAGE PERMIT REQUIRED                            |            4  |
# |  PHONE: DAMAGE LINE; PREVENT SUMMONING LAW ENF      |            4  |
# |  FUGITIVE: ON FELONY W/O WARRANT-EXTRADITION        |            4  |
# |  OBSTRUCT JUSTICE: RESIST ARREST BY THREATS/FORCE   |            4  |
# |  FIREARM: POSSESS BY FELON NONVIOLENT W/IN 10 YRS   |            4  |
# |  FALSE REPORT: FALSELY SUMMON/REPORT TO LAW ENF     |            4  |
# |  OBSTRUCT JUSTICE:FALSE INFO TO CRIM INVESTIGATOR   |            3  |
# |  ORDER: VIOLATION OF J&DR COURT ORDER               |            3  |
# |  STOLEN GOODS: BUY/RECEIVE, LARCENY <$200           |            3  |
# |  RESTRICTED LIC: VIOLATE RESTRICTIONS               |            3  |
# |  SHOPLIFT/ALTER PRICE: LARCENY >=$200               |            3  |
# |  WEAR MASKS IN CERTAIN PLACES                       |            3  |
# |  BURGLARY: ENTER HOUSE TO COMMIT LARCENY/A&B/ETC    |            3  |
# |  VEHICLE/AIRCRAFT/BOAT/ETC: DESTROY/INJURE          |            3  |
# |  UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY>200   |            3  |
# |  PHONE: ANNOYING RINGING                            |            3  |
# |  AGGRAVATED SEXUAL BATTERY: TYPE NOT CLEAR          |            3  |
# |  RECK DR: ON PARKING LOT/CLOSED HWY                 |            3  |
# |  RAPE, FORCIBLE - TYPE NOT CLEAR FROM RECORD        |            3  |
# |  TRAFFIC:EXPIRED TEMPORARY REGISTRATION             |            3  |
# |  SPEC LIC: DR BUS/CYCLE/COMM VEH W/O ENDORSEMENT    |            3  |
# |  VIOLATION OF VA STATE PARK REGULATIONS             |            3  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$500   |            3  |
# |  UNRESTRICTED DOG VIOL                              |            3  |
# |  CONSPIRING: TO COMMIT LARCENY > $200               |            3  |
# |  PROSTITUTION: USE VEHICLE TO AID                   |            3  |
# |  LARCENY: SECOND CONVICTION                         |            3  |
# |  DRUG PARAPHERNALIA: SELL/POSSESS TO SELL           |            3  |
# |  SODOMY, FORCIBLE - TYPE NOT CLEAR FROM RECORD      |            3  |
# |  IMPROPER USE OF DEALER TAGS                        |            2  |
# |  BAD CHECK: LARCENY <$200                           |            2  |
# |  COMMUNITY DIVERSION: VIOLATION ON MISDEMEANOR      |            2  |
# |  DRIVING WHILE OPERATORS LICENSE SUSPENDED OR REVOK |            2  |
# |  TRAFFIC:FAIL TO OBEY TRAFFIC LIGHTS                |            2  |
# |  STALKING: VIOLATION OF PROTECTIVE ORDER            |            2  |
# |  ANIMAL:INADEQUATE CARE OF ANIMAL(S) BY OWNER       |            2  |
# |  VEH DEALER: UNLAWFUL USE OF DEALER PLATES          |            2  |
# |  COMMER LIC: DR COMMERCIAL VEH W/O VALID LICENSE    |            2  |
# |  THROWING OR DEPOSITING CERTAIN SUBSTANCES UPON HIG |            2  |
# |  SEXUAL BATTERY: > 1 OCCASION OR >1 WITNESS         |            2  |
# |  DWI: 2ND OFF W/IN 10Y, BAC .15-.20%                |            2  |
# |  MASSAGE THERAPIST LICENSE REQUIRED                 |            2  |
# |  DWI: 3RD OFF W/IN 5Y - 10Y                         |            2  |
# |  VEHICLE/AIRCRAFT/BOAT/ETC: ENTER/SET IN MOTION     |            2  |
# |  BOMB/BURN THREAT: ACCUSED >=15Y                    |            2  |
# |  FIREARM: USE IN COMMISSION OF FELONY, 1ST OFF      |            2  |
# |  ROBBERY: STREET W/ USE OF GUN OR SIMULATED GUN     |            2  |
# |  MARIJUANA SYNTHETIC:POSSES CANNABIMIMETIC AGENT    |            2  |
# |  ABDUCTION: TO GAIN PECUNIARY BENEFIT (EXTORTION)   |            2  |
# |  PUBLIC RECORDS: EMPLOY AS TRUE, FORGERY            |            2  |
# |  THREAT: IN WRITING                                 |            2  |
# |  ACCIDENT: DRIVER NOT RPT, W/DEATH/INJ/DAMAG>1000   |            2  |
# |  ALCH BEV TEND/DRK  IN PUBLIC                       |            2  |
# |  PROSTITUTION: AID                                  |            2  |
# |  PROSTITUTION: RECEIVE EARNINGS (PANDERING)         |            2  |
# |  PROSTITUTION:RECEIVE MONEY TO PROCURE PROSTITUTE   |            2  |
# |  ALCOHOL: DRINKING/OFFER DRINK IN PUBLIC PLACE      |            2  |
# |  EMERGENCY SERVICES: CALL/SET ALARM W/O CAUSE       |            2  |
# |  RECK DR: SPEEDING, 20MPH+ OVER POSTED <=30MPH      |            2  |
# |  DRUGS: MARIJUANA, MANUFACTURE FOR OTHERS           |            2  |
# |  WEAPON: POSSESS BY FELON (NOT FIREARM)             |            2  |
# |  FIREARM: RECEIVE STOLEN OR AID IN CONCEALING       |            2  |
# |  DWI: 1ST OFF, BAC >.20%                            |            2  |
# |  ORDER: NOT COMPLY W/ J&DR COURT ORDER              |            2  |
# |  STOLEN PROPERTY: SELL/ETC, LARCENY >=$200          |            2  |
# |  FIREARM: POSSESS BY FELON W/ VIOLENT OFFENSE       |            2  |
# |  AGGRESSIVE DR: VIOL CERTAIN OFF + HAZARD/HARASS    |            2  |
# |  FIREARM: POSSESSION W/ SCH I OR II DRUG            |            2  |
# |  FIREARM: RECKLESS HANDLING                         |            2  |
# |  VEH WINDOWS: APPLY SUN-SHADING UNLAWFULLY, 1 OFF   |            2  |
# |  CREDIT CARD FRAUD: RECEIVE GOODS >=$200 IN 6M      |            2  |
# |  FUGITIVE: ARREST ON FELONY CHARGE PER 19.2-99      |            2  |
# |  DRIVING AFTER FORFEITURE OF LICENSE                |            2  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$250   |            1  |
# |  RECK DR: SPEEDING, DR 60MPH ON POSTED 35MPH        |            1  |
# |  NOISE PROHIBITIONS: SOUND AMPLIFICATION DEVICE (11 |            1  |
# |  BAIL/PRETRIAL SERVICES VIOLATION-MISD. FTA         |            1  |
# |  DWI: PERSON <21Y DRIVING W/ BAC .02% TO .07%       |            1  |
# |  INSUR:GIVE FALSE VEH INSUR INFO OR NOT SURRENDER   |            1  |
# |  COMMER LIC: DR VEH W/O REQUIRED LIC ENDORSEMENTS   |            1  |
# |  COUNTY HACKERS` LICENSE REQUIRED                   |            1  |
# |  OPERATOR LIC REQUIRED FOR TAXI DRV                 |            1  |
# |  PROBATION VIOLATION-MISDEMEANOR                    |            1  |
# |  ABUSE/NEGLECT CHILD: RECKLESS DISREGARD FOR LIFE   |            1  |
# |  COMMUNITY-BASED PROBATION: VIOLATION ON MISD OFF   |            1  |
# |  MALIC SHOOT OR THROW MISSILE IN/AT OCC. BLDG       |            1  |
# |  VEH INSPECTION STICKER: UNAUTHORIZED POSSESSION    |            1  |
# |  DISARM: LAW ENF/DOC OF FIREARM OR STUN-GUN         |            1  |
# |  DRUGS: MANUFACTURE, SCH I OR II                    |            1  |
# |  Z-IMPROPER REGISTRATION                            |            1  |
# |  RECK DR: LOAD/PASSENGERS INTERFERE W/ CONTROL      |            1  |
# |  WELFARE FRAUD: LARCENY >=$200                      |            1  |
# |  EMERG VEH: NOT APPROACH STOPPED VEH W/ CAUTION >=2 |            1  |
# |  ASSAULT: BY INMATE, PROBATIONER, ETC ON EMPLOYEE   |            1  |
# |  INDECENT EXPOSURE                                  |            1  |
# |  ROBBERY: RESIDENCE                                 |            1  |
# |  MOB: MALICIOUS WOUNDING                            |            1  |
# |  LICENSES REQUIRED                                  |            1  |
# |  DOG: NOT OBTAIN DANGER DOG REGSTRAT'N CERTIFICAT   |            1  |
# |  STOLEN GOODS:REC. GOODS USED IN INVSTGATN>=$200    |            1  |
# |  PEEP/SPY INTO DWELLING: THROUGH PEEPHOLE           |            1  |
# |  PEEP/SPY INTO DWELLING: THROUGH WINDOW/DOOR        |            1  |
# |  PRELIMINARY PROTECTIVE ORDER: VIOLATION            |            1  |
# |  ARSON: DWELLING USUALLY OCCUPIED                   |            1  |
# |  DOG: ORDINANCE-DANGEROUS DOG VIOLATION             |            1  |
# |  ROBBERY: BUSINESS                                  |            1  |
# |  ASSAULT: MALICIOUS, VICTIM SEVERELY INJURED        |            1  |
# |  RENT BY FRAUD: ANIMAL/AIRCRAFT/VEHICLE/BOAT        |            1  |
# |  ID THEFT:OBTN GOODS/SERVICE W/INTNT DEFRD>$200     |            1  |
# |  PROTECTIVE ORDER: VIOLATION (FAMILY ABUSE)         |            1  |
# |  TITLE/REGIST/PLATES: FRAUD                         |            1  |
# |  FUGITIVE: ARREST ON MISD CHARGE PER 19.2-99        |            1  |
# |  DRUGS:DISTRIB/PWI,ACCOMMODATE ANOTHER,MARIJUANA    |            1  |
# |  VEH INSPECTION STICKER: MAKE/USE COUNTERFEIT       |            1  |
# |  FAIL TO STOP FOR POLICE: ATT TO ESCAPE/ELUDE       |            1  |
# |  FIREARM: POSSESS BY NON VIOLENT FELON, >10 YRS     |            1  |
# |  LABOR/CUSTODY: ENDANGER/CRUELLY TREAT CHILD        |            1  |
# |  DWI: REFUSAL OF TEST, 1 OFF                        |            1  |
# |  BLDG CODE: UNSAFE DWELLING 1ST VIOL (ORDINANCE)    |            1  |
# |  STALKING: REASONABLE FEAR OF DEATH/ASSAULT/ETC     |            1  |
# |  RECK DR: NOT STOP BEFORE ENTERING HWY              |            1  |
# |  CONCEALED WEAPON: CARRY, 2 OFF                     |            1  |
# |  DRUGS: DISTRIB/PWI MARIJUANA >5 LBS                |            1  |
# |  BANK NOTES: FORGERY <10, OR EMPLOY AS TRUE         |            1  |
# |  COMMUNITY DIVERSION: VIOLATION ON FELONY OFF       |            1  |
# |  MONEY LAUNDERING: CONDUCT FINANCIAL TRANSACTION    |            1  |
# |  TRESPASS: POST UNAUTHORIZED "NO TRESPASS" SIGNS    |            1  |
# |  DWI: 3RD OFF W/IN 5Y                               |            1  |
# |  DRUGS: SELL/DISTRIB SCH III DRUG - NOT STEROID     |            1  |
# |  CREDIT CARD APPLICATION: FALSE STMT, FRAUD         |            1  |
# |  FAIL TO APPEAR ON TRAFFIC SUMMONS                  |            1  |
# |  ASSAULT: ON FAMILY MEMBER, 3RD+ OFFENSE            |            1  |
# |  OBJECT SEXUAL PENETRATION: TYPE NOT CLEAR          |            1  |
# |  PROTECTIVE ORDER                                   |            1  |
# |  CONTEMPT OF COURT: J&DR COURT                      |            1  |
# |  GRAND LARCENY: FIREARM, NOT FROM A PERSON          |            1  |
# |  MOTEL/RESTAURANT/PARK/ETC: FRAUD <$200             |            1  |
# |  PASS CARRIER: TNC REGIST/ID MARKER REQ             |            1  |
# |  ANNOYING RINGING TO EMERG SERVICES/ FALSE RPT      |            1  |
# |  RECK DR: RACING                                    |            1  |
# |  IMPERSONATION: LAW ENFORCEMENT                     |            1  |
# |  WARRANT - TEMPORARY DETENTION ORDER                |            1  |
# |  ALCOHOL SAFETY PROGRAM VIOLATION                   |            1  |
# |  PROTECTIVE ORDER: 3ND VIOL W/IN 20YRS              |            1  |
# |  PROTECTIVE ORDER: 2ND VIOL W/IN 5 YRS              |            1  |
# |  BURGLARY: ENTER HOUSE TO MURDER/RAPE/ETC, ARMED    |            1  |
# |  TRESPASS: SCHOOL/CHURCH PROPERTY                   |            1  |
# |  DRUGS: INHALING DRUGS OR NOXIOUS CHEMICALS         |            1  |
# |  CARJACKING                                         |            1  |
# |  DWI: REFUSAL OF BLOOD OR BREATH TEST, 3 OFF        |            1  |
# |  DWI: 4+ OFF W/IN 10Y                               |            1  |
# |  DRUGS: SELL/PROVIDE FOR RESALE SCH I OR II         |            1  |
# |  DRIVING AFTER FORFEITURE OF LICENSE:W/ BAC .02%+   |            1  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$250   |            1  |
# |  TRESPASS, FIRST OFFENDER VIOLATION                 |            1  |
# |  GANG: PARTICIPATE IN CRIM ACT W/ JUV IN SCH ZONE   |            1  |
# |  FIREARM: SHOOT IN PUBLIC PLACE, NOT CAUSE INJURY   |            1  |
# |  ABDUCTION: BY PARENT, REMOVE FROM STATE            |            1  |
# |  RECKLESS DRIVING GENERALLY.                        |            1  |
# |  SCH ATTEND: NOT COMPLY W/ COMPULSORY ATTENDANCE    |            1  |
# |  DWI: 2ND OFF W/IN 5Y, BAC >.20%                    |            1  |
# |  LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 2+OFF   |            1  |
# |  ENTER A SCHOOL AFT CONVICTED OF SEX OFFENSE        |            1  |
# |  <15Y TO PERFORM PORN, OFFENDR 7+ YRS OLDER, 2ND    |            1  |
# |  PAROLE VIOLATION-FELONY                            |            1  |
# |  RECK DR: NOT STOP FOR SCH BUS + REV LIC & DEATH    |            1  |
# |  TITLE: POSSESS TITLE ISSUED TO ANOTHER             |            1  |
# |  DOG: FAIL TO CONTROL/RESULTS IN SERIOUS INJURY     |            1  |
# |  FALSE STATEMENTS: HOUSING AID                      |            1  |
# |  ACCIDENT: DRIVER NOT RPT, W/DEATH/INJURY           |            1  |
# |  LARCENY - SHOPLIFTING                              |            1  |
# |  LAW ENF COMMAND: DISREGARD OR ELUDE, ENDANGER      |            1  |
# |  TITLE/SALVAGE: OBTAIN/CREATE FALSE DOCS, FRAUD     |            1  |
# |                                                     |            0  |
# |-----------------------------------------------------+---------------|

# %% [markdown]
# There's a lot of data here, but be sure to focus on the last row - it's blank, and the count is 0, which means there are no rows that are missing a Charge Descrip. That's good, because it means we have no missing data in that column. You can try the same process out using another column like `Age` or `FName`.
#
# Let's now look at **Gaps in Data**. It's been my experience that gaps in data often have to do with time, so let's first look at arrests by month, so we can see what our arrest data covers. You'd expect the number to change, but not by huge amounts. Huge differences could indicate, more often than not, that the data is missing. To do this, we'll need to calculate the month from the date.

# %%
arrests_with_months = arrests.compute([
    ('arrest_month', agate.Formula(agate.Text(), lambda row: '%s' % row['DateArr'].month))
])

# %%
months = arrests_with_months.group_by('arrest_month')

# %%
month_counts = months.aggregate([
    ('count', agate.Count('Charge Descrip'))
])
month_counts = month_counts.order_by('count', reverse=True)

# %%
month_counts.print_table()
# Out:
# |---------------+--------|
# |  arrest_month | count  |
# |---------------+--------|
# |  2            | 2,949  |
# |  1            |   164  |
# |  12           |   130  |
# |  11           |    99  |
# |  10           |    72  |
# |  9            |    60  |
# |  8            |    13  |
# |  4            |     5  |
# |  6            |     4  |
# |  5            |     2  |
# |  3            |     1  |
# |---------------+--------|

# %% [markdown]
# This looks a little weird. Yes, the bulk of charges came in February, which is pretty recent, with smaller amounts in January and December. But 60 from September and 72 from October? What's with those? This would mean additional reporting - maybe this is standard practice, or can be easily explained. Maybe an analysis would just include arrest records from the most recent month.
#
# Looks like we should compile some questions to ask the Fairfax County Police Department.

# %% [markdown]
# ### Assignment
#
# What about the Age column - are there outliers there, and what does Age tell you about the contents of the dataset? Is Address data standardized, or are there variations? Are there errors, like misspellings, in the data? Are there outliers? What are the more interesting and potentially newsworthy charges? What steps in [Agate](https://agate.readthedocs.org/en/1.3.0/) can you take to find out?
#
# Try exploring the data using some of the steps listed above, but with other columns. You can use many of the same functions we have, just change the column name. Add them to this notebook, along with some questions you'd ask the Fairfax police, then add, commit and push this notebook file (`arrests.ipynb`) to Github.
