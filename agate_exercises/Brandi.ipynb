# %% [markdown]
# ## Data Smells
#
# Any time you are given a dataset from anyone, you should immediately be suspicious. Is this data what I think it is? Does it include what I expect? Is there anything I need to know about it? Will it produce the information I expect?
#
# One of the first things you should do is give it the smell test.
#
# Failure to give data the smell test [can lead you to miss stories and get your butt kicked on a competitive story](https://source.opennews.org/en-US/learning/handling-data-about-race-and-ethnicity/).
#
# Let's look at arrest data for Fairfax County, Va. You can find the `arrest.csv` file in this repository.

# %%
import agate
arrests = agate.Table.from_csv('arrest.csv')

# %% [markdown]
# With data smells, we're trying to find common mistakes in data. For more on data smells, read the GitHub wiki post that started it all. The common mistakes we're looking for are:
#
# * Missing data
# * Gaps in data
# * Wrong type of data
# * Outliers
# * Sharp curves
# * Conflicting information within a dataset
# * Conflicting information across datasets
# * Wrongly derived data
# * External inconsistency
# * Wrong spatial data
# * Unusuable data, including non-standard abbreviations, ambigious data, extraneous data, inconsistent data
#
# Not all of these data smells are detectable in code. You may have to ask people about the data. You may have to compare it to another dataset yourself. Does the agency that uses the data produce reports from the data? Does your analysis match those reports? That will expose wrongly derived data, or wrong units, or mistakes you made with inclusion or exclusion.
#
# But with several of these data smells, we can do them first, before we do anything else. First, let's look at **Wrong Type Of Data**. We can sniff that out by simply printing the table structure that Agate has discovered for us.

# %%
print arrests
# Out:
# |-----------------+---------------|
# |  column_names   | column_types  |
# |-----------------+---------------|
# |  LName          | Text          |
# |  FName          | Text          |
# |  MName          | Text          |
# |  Age            | Number        |
# |  DateArr        | Date          |
# |  Charge         | Text          |
# |  Charge Descrip | Text          |
# |  Address        | Text          |
# |-----------------+---------------|

# %% [markdown]
# Things seem to look good for this file. The name columns are text, the age column is a number, the date is a date, etc.
#
# The second smell we can find in Agate is Missing Data. We can do that through a series of Group By and Count steps. Let's start with Charge Descrip.

# %%
charges = arrests.group_by('Charge Descrip')
median_age = charges.aggregate([('median_age', agate.Median('Age'))])
median_age = age_median.order_by('median_age', reverse=True)

# %%
age_median.print_table(max_column_width=50)
# Out:
# |---------------------------------------------------+-------------|
# |  Charge Descrip                                   | median_age  |
# |---------------------------------------------------+-------------|
# |  MOTEL/RESTAURANT/PARK/ETC: FRAUD <$200           |       65.0  |
# |  PROTECTIVE ORDER: 3ND VIOL W/IN 20YRS            |       60.0  |
# |  PROTECTIVE ORDER: 2ND VIOL W/IN 5 YRS            |       60.0  |
# |  DWI: 1ST OFF, BAC >.20%                          |       57.5  |
# |  FIREARM: POSSESS BY NON VIOLENT FELON, >10 YRS   |       57.0  |
# |  PHONE: ANNOYING RINGING                          |       55.0  |
# |  ENTER A SCHOOL AFT CONVICTED OF SEX OFFENSE      |       55.0  |
# |  EMERGENCY SERVICES: CALL/SET ALARM W/O CAUSE     |       54.5  |
# |  AGGRESSIVE DR: VIOL CERTAIN OFF + HAZARD/HARASS  |       53.0  |
# |  MALIC SHOOT OR THROW MISSILE IN/AT OCC. BLDG     |       52.0  |
# |  DRUGS: MANUFACTURE, SCH I OR II                  |       51.0  |
# |  LARCENY: THIRD OR SUBSEQUENT CONVICTION          |       51.0  |
# |  ALCH BEV TEND/DRK  IN PUBLIC                     |       50.0  |
# |  ORDER: VIOLATION OF J&DR COURT ORDER             |       49.0  |
# |  ABDUCTION: BY PARENT, REMOVE FROM STATE          |       49.0  |
# |  DOG: FAIL TO CONTROL/RESULTS IN SERIOUS INJURY   |       49.0  |
# |  MONEY LAUNDERING: CONDUCT FINANCIAL TRANSACTION  |       48.0  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$250 |       48.0  |
# |  UNVACCINATED DOG OR CAT                          |       47.0  |
# |  BAD CHECK: LARCENY <$200                         |       47.0  |
# |  ...                                              |        ...  |
# |---------------------------------------------------+-------------|

# %% [markdown]
# There's a lot of data here, but be sure to focus on the last row - it's blank, and the count is 0, which means there are no rows that are missing a Charge Descrip. That's good, because it means we have no missing data in that column. You can try the same process out using another column like `Age` or `FName`.
#
# Let's now look at **Gaps in Data**. It's been my experience that gaps in data often have to do with time, so let's first look at arrests by month, so we can see what our arrest data covers. You'd expect the number to change, but not by huge amounts. Huge differences could indicate, more often than not, that the data is missing. To do this, we'll need to calculate the month from the date.

# %%
arrests_with_months = arrests.compute([
    ('arrest_month', agate.Formula(agate.Text(), lambda row: '%s' % row['DateArr'].month))
])

# %%
months = arrests_with_months.group_by('arrest_month')

# %%
month_counts = months.aggregate([
    ('count', agate.Count('Charge Descrip'))
])
month_counts = month_counts.order_by('count', reverse=True)

# %%
month_counts.print_table()
# Out:
# |---------------+--------|
# |  arrest_month | count  |
# |---------------+--------|
# |  2            | 2,949  |
# |  1            |   164  |
# |  12           |   130  |
# |  11           |    99  |
# |  10           |    72  |
# |  9            |    60  |
# |  8            |    13  |
# |  4            |     5  |
# |  6            |     4  |
# |  5            |     2  |
# |  3            |     1  |
# |---------------+--------|

# %% [markdown]
# This looks a little weird. Yes, the bulk of charges came in February, which is pretty recent, with smaller amounts in January and December. But 60 from September and 72 from October? What's with those? This would mean additional reporting - maybe this is standard practice, or can be easily explained. Maybe an analysis would just include arrest records from the most recent month.
#
# Looks like we should compile some questions to ask the Fairfax County Police Department.

# %% [markdown]
# ### Assignment
#
# What about the Age column - are there outliers there, and what does Age tell you about the contents of the dataset? Is Address data standardized, or are there variations? Are there errors, like misspellings, in the data? Are there outliers? What are the more interesting and potentially newsworthy charges? What steps in [Agate](https://agate.readthedocs.org/en/1.3.0/) can you take to find out?
#
# Try exploring the data using some of the steps listed above, but with other columns. You can use many of the same functions we have, just change the column name. Add them to this notebook, along with some questions you'd ask the Fairfax police, then add, commit and push this notebook file (`arrests.ipynb`) to Github.

# %%
ages = arrests.group_by('Age')
age_counts = ages.aggregate([('age', agate.Count('Age'))])
age_counts = age_counts.order_by('Age', reverse=True)
age_counts.print_table(max_column_width=50)
# Out:
# |------+------|
# |  Age | age  |
# |------+------|
# |   88 |   1  |
# |   86 |   1  |
# |   83 |   1  |
# |   78 |   4  |
# |   76 |   3  |
# |   73 |   1  |
# |   72 |   2  |
# |   71 |   3  |
# |   70 |   3  |
# |   69 |   5  |
# |   67 |   5  |
# |   66 |   2  |
# |   65 |   5  |
# |   64 |   4  |
# |   63 |   7  |
# |   62 |  14  |
# |   61 |   5  |
# |   60 |  16  |
# |   59 |  18  |
# |   58 |  14  |
# |   57 |  24  |
# |   56 |  23  |
# |   55 |  29  |
# |   54 |  33  |
# |   53 |  26  |
# |   52 |  28  |
# |   51 |  29  |
# |   50 |  42  |
# |   49 |  27  |
# |   48 |  40  |
# |   47 |  46  |
# |   46 |  31  |
# |   45 |  48  |
# |   44 |  63  |
# |   43 |  43  |
# |   42 |  57  |
# |   41 |  52  |
# |   40 |  36  |
# |   39 |  67  |
# |   38 |  64  |
# |   37 |  72  |
# |   36 |  75  |
# |   35 |  88  |
# |   34 |  71  |
# |   33 |  95  |
# |   32 | 121  |
# |   31 | 124  |
# |   30 | 137  |
# |   29 | 111  |
# |   28 | 119  |
# |   27 | 169  |
# |   26 | 145  |
# |   25 | 160  |
# |   24 | 158  |
# |   23 | 159  |
# |   22 | 177  |
# |   21 | 161  |
# |   20 | 144  |
# |   19 | 167  |
# |   18 | 137  |
# |------+------|

# %%
print arrests.rows[0]['Address']
# Out:
# 5215 HARBOR COURT DR, ALEXANDRIA, VA 22315

# %%
alex = arrests.where(lambda row: 'ALEX' in row['Address'])

# %%
print alex.rows[3] ['Address']
# Out:
# 3714 NORTH ROSSER STREET, 202, ALEXANDRIA, VA 22311

# %%
print len(alex.rows)
# Out:
# 656

# %%
for row in alex.rows: 
    print row('Address')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-419887ff9a48> in <module>()
#       1 for row in alex.rows:
# ----> 2     print row('Address')
#
# TypeError: 'Row' object is not callable

# %%
for row in arrests.rows:
    print row['Charge Descrip']
# Out:
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# GRAND LARCENY: $200+ NOT FROM A PERSON
# BURGLARIOUS TOOLS: POSSESSION OF
# IDENTITY THEFT: OBTAIN ID TO DEFRAUD
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# TRESPASS: AFTER BEING FORBIDDEN TO DO SO
# LICENSE: DRIVE W/O, 2+ OFFENSE
# FAILURE TO APPEAR: ON FELONY OFFENSE
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS SCH I OR II
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# INSUR: OPERATE UNINSURED VEH
# INSUR: OPERATE UNINSURED VEH
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ASSAULT: ON FAMILY MEMBER
# PHONE: INJURE/TAP LINE; COPY/OBSTRUCT MESSAGE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# ASSAULT: ON FAMILY MEMBER
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# POSS OPEN ALCH CONT
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$250
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RECK DR: DR TOO FAST FOR HWY CONDITIONS
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# RECKLE/20 MPH OVER LIMIT
# IMPROPER USE OF DEALER TAGS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECKL/SPEED OVER 80 MPH
# INSUR: OPERATE UNINSURED VEH
# RECK DR: SPEEDING 20MPH+
# RECKLE/20 MPH OVER LIMIT
# DISREG POLICE SIGNAL TO STOP,EL
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# OPERATE VEHICLE WITH SUN-SHADING/TINTING FILMS
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# MALICIOUS BODILY INJURY
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# INSUR: OPERATE UNINSURED VEH
# LICENSE: DRIVE W/O, 2+ OFFENSE
# RECK DR: SPEEDING, DR 60MPH ON POSTED 35MPH
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# MALICIOUS WOUNDING
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# RUNNING AT LARGE
# NOISE PROHIBITIONS: SOUND AMPLIFICATION DEVICE (11
# RECKL/SPEED OVER 80 MPH
# LICENSE: DRIVE W/O
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PROBATION: VIOLATION ON FELONY OFFENSE
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# RECK DR: DR TOO FAST FOR HWY CONDITIONS
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DRINKING WHILE DRIVING OR OPEN CONTAINER
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DWI: 2ND OFF W/IN 5Y
# OBSTRUCT JUSTICE: W/ THREATS/FORCE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O
# LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# BAIL/PRETRIAL SERVICES VIOLATION-MISD. FTA
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS
# DRUNK IN PUBLIC OR PROFANE
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# GRAND LARCENY: AUTO THEFT
# DWI: PERSON <21Y DRIVING W/ BAC .02% TO .07%
# ENTER PROPERTY TO DAMAGE, ETC.:
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# UNLICENSED DOG
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# EMBEZZLEMENT: <$200
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# UNVACCINATED DOG OR CAT
# UNVACCINATED DOG OR CAT
# UNVACCINATED DOG OR CAT
# UNLICENSED DOG
# UNLICENSED DOG
# UNLICENSED DOG
# INSUR: OPERATE UNINSURED VEH
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# DWI: 1ST OFF, BAC .15-.20%
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# DRUGS: POSSESS SCH I OR II
# DWI: 1ST OFFENSE
# DRINKING WHILE DRIVING OR OPEN CONTAINER
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# ENTER PROPERTY TO DAMAGE, ETC.:
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# MONUMENT: INTENTIONAL DAMAGE, VALUE <$1000
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: ON FAMILY MEMBER
# BAD CHECK: LARCENY <$200
# BAD CHECK: LARCENY <$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# OBSTRUCT JUSTICE:FALSE INFO TO CRIM INVESTIGATOR
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS SCH IV
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DWI: 1ST OFF, BAC .15-.20%
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# DWI: 1ST OFFENSE
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING 20MPH+
# LICENSE: DRIVE W/O
# ORDER: VIOLATION OF J&DR COURT ORDER
# ASSAULT: (MISDEMEANOR)
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# POSS OPEN ALCH CONT
# DRUGS: POSSESS W/INTENT TO MANUF/SELL SCH I, II
# RECK DR: SPEEDING 20MPH+
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS SCH III
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# INSUR: OPERATE UNINSURED VEH
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ASSAULT: (MISDEMEANOR)
# RECK DR: SPEEDING 20MPH+
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# EMBEZZLEMENT: <$200
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ASSAULT: ON FAMILY MEMBER
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR:GIVE FALSE VEH INSUR INFO OR NOT SURRENDER
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# GRAND LARCENY: $200+ NOT FROM A PERSON
# POSS OPEN ALCH CONT
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# DWI: 1ST OFF, BAC .15-.20%
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# COMMUNITY DIVERSION: VIOLATION ON MISDEMEANOR
# RECK DR: SPEEDING 20MPH+
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O, 2+ OFFENSE
# DWI: 1ST OFFENSE
# INSUR: OPERATE UNINSURED VEH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 2ND OFF W/IN 5Y - 10Y
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 2 OFF
# DRIVING WHILE OPERATORS LICENSE SUSPENDED OR REVOK
# LICENSE: DRIVE W/O
# INSUR: OPERATE UNINSURED VEH
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# TRESPASS-POSTED OR ADVISED TO LV
# LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 1 OFF
# TRAFFIC:FAIL TO OBEY TRAFFIC LIGHTS
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# STALKING: VIOLATION OF PROTECTIVE ORDER
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O, 2+ OFFENSE
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# FAILURE TO APPEAR: ON FELONY OFFENSE
# LICENSE: DRIVE W/O
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# DRUNK IN PUBLIC OR PROFANE
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 1 OFF
# COMMER LIC: DR VEH W/O REQUIRED LIC ENDORSEMENTS
# POSS OPEN ALCH CONT
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# DISORDERLY CONDUCT
# TRESPASS-POSTED OR ADVISED TO LV
# OBSTRUCT JUSTICE: W/ THREATS/FORCE
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# TRESPASS-POSTED OR ADVISED TO LV
# DISORDERLY CONDUCT
# DWI: 1ST OFFENSE
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ANIMAL:INADEQUATE CARE OF ANIMAL(S) BY OWNER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# TRESPASS: AFTER BEING FORBIDDEN TO DO SO
# PROFANE SWEARING OR INTOXICATION IN PUBLIC
# ASSAULT: ON FAMILY MEMBER
# FIREARM/ETC: POINTING/BRANDISHING
# DRIVE WHILE REVOKED-DWI
# VEH DEALER: UNLAWFUL USE OF DEALER PLATES
# LICENSE: DRIVE W/O
# INSUR: OPERATE UNINSURED VEH
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECKLE/20 MPH OVER LIMIT
# CONTRIBUTE TO DELINQUENCY OF MINOR
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DISORDERLY CONDUCT
# RECKLE/20 MPH OVER LIMIT
# COUNTY HACKERS` LICENSE REQUIRED
# OPERATOR LIC REQUIRED FOR TAXI DRV
# LICENSE: DRIVE W/O
# POSS OPEN ALCH CONT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# PROBATION VIOLATION-FELONY
# PROBATION VIOLATION-FELONY
# PROBATION VIOLATION-FELONY
# PROBATION VIOLATION-MISDEMEANOR
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LICENSE: DRIVE W/O
# DWI: 2ND OFF W/IN 5Y - 10Y
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 2 OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# PROBATION: VIOLATION ON MISDEMEANOR OFFENSE
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# GRAND LARCENY: $5+ FROM A PERSON (PICK POCKET)
# BURGLARY: ENTER BLDG TO COMMIT LARCENY/A&B/ETC
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# ABUSE/NEGLECT CHILD: RECKLESS DISREGARD FOR LIFE
# DRUGS: POSSESS SCH IV
# STOLEN GOODS: BUY/RECEIVE, LARCENY <$200
# STOLEN GOODS: BUY/RECEIVE, LARCENY <$200
# MONUMENT: INTENTIONAL DAMAGE, VALUE <$1000
# MONUMENT: INTENTIONAL DAMAGE, VALUE <$1000
# COMMER LIC: DR COMMERCIAL VEH W/O VALID LICENSE
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# RESISTING ARREST
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# COMMUNITY-BASED PROBATION: VIOLATION ON MISD OFF
# PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG
# DRUNK IN PUBLIC OR PROFANE
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# RESTRICTED LIC: VIOLATE RESTRICTIONS
# LICENSE: DRIVE W/O
# UNLICENSED DOG
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS SCH I OR II
# ALCOHOL: PURCH/POSSESS BY PERSON <21Y
# IDENTITY THEFT: POSSESS FICTITIOUS ID CARD
# EMBEZZLEMENT: >=$200
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# EMBEZZLEMENT: >=$200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# CONTRIBUTE TO DELINQUENCY OF MINOR
# BURGLARIOUS TOOLS: POSSESSION OF
# SHOPLIFT/ALTER PRICE: LARCENY >=$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DWI: 1ST OFF, BAC .15-.20%
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# MALIC SHOOT OR THROW MISSILE IN/AT OCC. BLDG
# MONUMENT: INTENTIONAL DAMAGE, VALUE >=$1000
# VEH INSPECTION STICKER: UNAUTHORIZED POSSESSION
# PROBATION: VIOLATION ON FELONY OFFENSE
# TRESPASS-POSTED OR ADVISED TO LV
# PROFANE SWEARING OR INTOXICATION IN PUBLIC
# RESISTING ARREST
# WEAR MASKS IN CERTAIN PLACES
# DISARM: LAW ENF/DOC OF FIREARM OR STUN-GUN
# LICENSE: DRIVE W/O
# TRESPASS-POSTED OR ADVISED TO LV
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# BURGLARY: ENTER HOUSE TO COMMIT LARCENY/A&B/ETC
# GRAND LARCENY: $5+ FROM A PERSON (PICK POCKET)
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# PLATES/DECALS: POSSESS/FORGED
# PLATES/DECALS: POSSESS/FORGED
# PETIT LARCENY: <$200 NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# RECK DR: SPEEDING 20MPH+
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FORGERY: OBTAIN SIGNATURE BY FALSE PRETENSE
# RESTRICTED LIC: VIOLATE RESTRICTIONS
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# BAILEE: VIOLATE CONDITION OF RELEASE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# ASSAULT: ON FAMILY MEMBER
# THROWING OR DEPOSITING CERTAIN SUBSTANCES UPON HIG
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 2ND OFF W/IN 5Y - 10Y
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 2 OFF
# DRUGS: MANUFACTURE, SCH I OR II
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: (MISDEMEANOR)
# ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# CONCEALED WEAPON: CARRY
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# PUBLIC RECORDS: FORGERY
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD FORGERY DEVICES: POSSESS
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LICENSE: DRIVE W/O
# DRIVE WHILE REVOKED-DWI
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RESTRICTED LIC: VIOLATE RESTRICTIONS
# RECK DR: SPEEDING, OVER 80MPH
# SEXUAL BATTERY: > 1 OCCASION OR >1 WITNESS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O, 2+ OFFENSE
# None
# Z-IMPROPER REGISTRATION
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# POSS OPEN ALCH CONT
# DWI: 2ND OFF W/IN 5Y
# VEHICLE/AIRCRAFT/BOAT/ETC: DESTROY/INJURE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PLATES/DECALS: POSSESS/FORGED
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# ASSAULT: (MISDEMEANOR)
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200
# ASSAULT: ON FAMILY MEMBER
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# ENTER PROPERTY TO DAMAGE, ETC.:
# MONUMENT: UNLAWFUL DAMAGE, NO INTENT TO STEAL
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# UNVACCINATED DOG OR CAT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# RECKL/SPEED OVER 80 MPH
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# FAILURE TO APPEAR: ON FELONY OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# RECK DR: LOAD/PASSENGERS INTERFERE W/ CONTROL
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# DWI: 1ST OFFENSE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# LICENSE: DRIVE W/O
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD FRAUD: BY PERSON>=$200 IN 6M
# GRAND LARCENY: $200+ NOT FROM A PERSON
# POSS OPEN ALCH CONT
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PROBATION: VIOLATION ON FELONY OFFENSE
# PROBATION: VIOLATION ON FELONY OFFENSE
# UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY>200
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O, 2+ OFFENSE
# DWI: 2ND OFF W/IN 10Y, BAC .15-.20%
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# PROFANE SWEARING OR INTOXICATION IN PUBLIC
# LICENSE: DRIVE W/O
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# TRESPASS-POSTED OR ADVISED TO LV
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# CONTRIBUTE TO DELINQUENCY OF MINOR
# CONTRIBUTE TO DELINQUENCY OF MINOR
# CONTRIBUTE TO DELINQUENCY OF MINOR
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING 20MPH+
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# RECK DR: SPEEDING, OVER 80MPH
# RECKLE/20 MPH OVER LIMIT
# PETIT LARCENY: <$200 NOT FROM A PERSON
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# PHONE: ANNOYING RINGING
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# WELFARE FRAUD: LARCENY >=$200
# LICENSE: DRIVE W/O
# AGGRAVATED SEXUAL BATTERY: TYPE NOT CLEAR
# AGGRAVATED SEXUAL BATTERY: TYPE NOT CLEAR
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# ASSAULT: (MISDEMEANOR)
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# POSS OPEN ALCH CONT
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# MASSAGE THERAPIST LICENSE REQUIRED
# PETIT LARCENY: <$200 NOT FROM A PERSON
# VEHICLE/AIRCRAFT/BOAT/ETC: DESTROY/INJURE
# ASSAULT: (MISDEMEANOR)
# LICENSE: DRIVE W/O
# DRUGS: POSSESS SCH I OR II
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DWI: 3RD OFF W/IN 5Y - 10Y
# PROTECTIVE ORDER: VIOLATION
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/PWI MARIJUANA <1/2 OZ
# DRIVING WHILE OPERATORS LICENSE SUSPENDED OR REVOK
# ASSAULT: ON FAMILY MEMBER
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RECKLE/20 MPH OVER LIMIT
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# POSS OPEN ALCH CONT
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170
# OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170
# OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170
# OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# DWI: 1ST OFFENSE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# EMERG VEH: NOT APPROACH STOPPED VEH W/ CAUTION >=2
# INSUR: OPERATE UNINSURED VEH
# RECK DR: ON PARKING LOT/CLOSED HWY
# LICENSE: DRIVE W/O
# RAPE, FORCIBLE - TYPE NOT CLEAR FROM RECORD
# ABDUCTION: BY FORCE, INTIMIDATION OR DECEPTION
# PHONE: INJURE/TAP LINE; COPY/OBSTRUCT MESSAGE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: BY INMATE, PROBATIONER, ETC ON EMPLOYEE
# TRESPASS-POSTED OR ADVISED TO LV
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS SCH I OR II
# ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000
# LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 1 OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# RESISTING ARREST
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECKLE/20 MPH OVER LIMIT
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# ASSAULT: ON FAMILY MEMBER
# CONTRIBUTE TO DELINQUENCY OF MINOR
# DWI: 1ST OFFENSE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# TRAFFIC:EXPIRED TEMPORARY REGISTRATION
# LICENSE: DRIVE W/O
# DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# SPEC LIC: DR BUS/CYCLE/COMM VEH W/O ENDORSEMENT
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# POSS OPEN ALCH CONT
# VIOLATION OF VA STATE PARK REGULATIONS
# ASSAULT: (MISDEMEANOR)
# INDECENT EXPOSURE
# RECK DR: SPEEDING 20MPH+
# DRINKING WHILE DRIVING OR OPEN CONTAINER
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# LICENSE: DRIVE W/O
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# GRAND LARCENY: $200+ NOT FROM A PERSON
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# DWI: 1ST OFF, BAC .15-.20%
# DRIVE WHILE REVOKED-DWI
# INSUR: OPERATE UNINSURED VEH
# PLATES/DECALS: POSSESS/FORGED
# LICENSE: DRIVE W/O
# LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR
# DRUNK IN PUBLIC OR PROFANE
# DISORDERLY CONDUCT
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# RESISTING ARREST
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ROBBERY: RESIDENCE
# MOB: MALICIOUS WOUNDING
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROTECTIVE ORDER: VIOLATION
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# DWI: 2ND OFF W/IN 5Y
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# DWI: 1ST OFF, BAC .15-.20%
# LICENSE: DRIVE W/O
# DRINKING WHILE DRIVING OR OPEN CONTAINER
# PROBATION: VIOLATION ON MISDEMEANOR OFFENSE
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR
# GRAND LARCENY: $200+ NOT FROM A PERSON
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# ROBBERY: ON OR NEAR STREET
# ASSAULT: (MISDEMEANOR)
# PROBATION: VIOLATION ON MISDEMEANOR OFFENSE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FAILURE TO APPEAR: ON FELONY OFFENSE
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING 20MPH+
# LICENSES REQUIRED
# VEHICLE/AIRCRAFT/BOAT/ETC: ENTER/SET IN MOTION
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# DRUNK IN PUBLIC OR PROFANE
# OBSTRUCT JUSTICE:FALSE INFO TO CRIM INVESTIGATOR
# LICENSE: DRIVE W/O
# POSS OPEN ALCH CONT
# LICENSE: DRIVE W/O
# DISREG POLICE SIGNAL TO STOP,EL
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# ASSAULT: (MISDEMEANOR)
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ROBBERY: ON OR NEAR STREET
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING 20MPH+
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# FAILURE TO APPEAR: ON FELONY OFFENSE
# BOMB/BURN THREAT: ACCUSED >=15Y
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$500
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DWI: 1ST OFFENSE
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# MALICIOUS WOUNDING
# FIREARM: USE IN COMMISSION OF FELONY, 1ST OFF
# ROBBERY: STREET W/ USE OF GUN OR SIMULATED GUN
# DRUNK IN PUBLIC OR PROFANE
# PROSTITUTION
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# DRINKING WHILE DRIVING OR OPEN CONTAINER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 1ST OFFENSE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# RECK DR: GENERALLY + REV LIC & CAUSE DEATH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# SHOPLIFT/ALTER PRICE: LARCENY >=$200
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# DWI: 1ST OFFENSE
# DRUNK IN PUBLIC OR PROFANE
# TRESPASS-POSTED OR ADVISED TO LV
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# TRESPASS SCH FORBIDDEN
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# DOG: NOT OBTAIN DANGER DOG REGSTRAT'N CERTIFICAT
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# DISORDERLY CONDUCT
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# PETIT LARCENY: <$200 NOT FROM A PERSON
# ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y
# ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y
# ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y
# ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y
# ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y
# PETIT LARCENY: <$5 FROM A PERSON (PICK POCKET)
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# TRESPASS SCH FORBIDDEN
# DRUNK IN PUBLIC OR PROFANE
# POSS OPEN ALCH CONT
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# PETIT LARCENY: <$5 FROM A PERSON (PICK POCKET)
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# STOLEN GOODS:REC. GOODS USED IN INVSTGATN>=$200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUNK IN PUBLIC OR PROFANE
# ASSAULT: (MISDEMEANOR)
# ASSAULT: (MISDEMEANOR)
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# PETIT LARCENY: <$200 NOT FROM A PERSON
# MARIJUANA SYNTHETIC:POSSES CANNABIMIMETIC AGENT
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING, OVER 80MPH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# INSUR: OPERATE UNINSURED VEH
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# DRUNK IN PUBLIC OR PROFANE
# TRESPASS-POSTED OR ADVISED TO LV
# PROSTITUTION
# RECKL/SPEED OVER 80 MPH
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# INSUR: OPERATE UNINSURED VEH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# TRESPASS-POSTED OR ADVISED TO LV
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PEEP/SPY INTO DWELLING: THROUGH PEEPHOLE
# PEEP/SPY INTO DWELLING: THROUGH WINDOW/DOOR
# PETIT LARCENY: <$200 NOT FROM A PERSON
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# MASSAGE PERMIT REQUIRED
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# None
# LICENSE: DRIVE W/O
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DRUNK IN PUBLIC OR PROFANE
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# POSS OPEN ALCH CONT
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# CREDIT CARD FORGERY
# CREDIT CARD FORGERY
# CREDIT CARD FRAUD: BY PERSON>=$200 IN 6M
# CREDIT CARD FORGERY DEVICES: POSSESS
# CREDIT CARD FORGERY
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# DRUGS: POSSESS SCH I OR II
# BAILEE: VIOLATE CONDITION OF RELEASE
# TRESPASS-POSTED OR ADVISED TO LV
# RECK DR: SPEEDING 20MPH+
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: MANUF/DISTRIBUTE ON CERTAIN PROPERTIES
# DRUGS: MANUF/DISTRIBUTE ON CERTAIN PROPERTIES
# DRUGS: POSSESS SCH I OR II
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# MONUMENT: UNLAWFUL DAMAGE, NO INTENT TO STEAL
# PROTECTIVE ORDER: VIOLATION
# EMBEZZLEMENT: <$200
# EMBEZZLEMENT: <$200
# EMBEZZLEMENT: <$200
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# FAILURE TO APPEAR: ON FELONY OFFENSE
# FAILURE TO APPEAR: ON FELONY OFFENSE
# OPERATE VEHICLE WITH SUN-SHADING/TINTING FILMS
# DWI: 1ST OFFENSE
# DISREG POLICE SIGNAL TO STOP,EL
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# RECKL/SPEED OVER 80 MPH
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD FORGERY
# CREDIT CARD FORGERY
# CREDIT CARD FORGERY
# PUBLIC RECORDS: FORGERY
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# DWI: 1ST OFFENSE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUGS: POSSESS SCH I OR II
# DRUNK IN PUBLIC OR PROFANE
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# RESISTING ARREST
# CONTRIBUTE TO DELINQUENCY OF MINOR
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# ABDUCTION: BY FORCE, INTIMIDATION OR DECEPTION
# ASSAULT: (MISDEMEANOR)
# ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# INSUR: OPERATE UNINSURED VEH
# DRIVE WHILE REVOKED-DWI
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: SPEEDING 20MPH+
# DRUNK IN PUBLIC OR PROFANE
# ENTER PROPERTY TO DAMAGE, ETC.:
# LICENSE: DRIVE W/O
# DWI: 1ST OFF, BAC .15-.20%
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# MASSAGE PERMIT REQUIRED
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# TRESPASS-POSTED OR ADVISED TO LV
# LICENSE: DRIVE W/O
# INSUR: OPERATE UNINSURED VEH
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# IDENTITY THEFT: POSSESS FICTITIOUS ID CARD
# LICENSE: DRIVE W/O, 2+ OFFENSE
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# ENTER PROPERTY TO DAMAGE, ETC.:
# PRELIMINARY PROTECTIVE ORDER: VIOLATION
# ARSON: DWELLING USUALLY OCCUPIED
# BOMB/BURN THREAT: ACCUSED >=15Y
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# IDENTITY THEFT: OBTAIN ID TO DEFRAUD
# None
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DISORDERLY CONDUCT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# DISORDERLY CONDUCT
# EMBEZZLEMENT: >=$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# UNLICENSED DOG
# UNLICENSED DOG
# RUNNING AT LARGE
# DOG: ORDINANCE-DANGEROUS DOG VIOLATION
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# DWI: 1ST OFFENSE
# RECK DR: SPEEDING 20MPH+
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ROBBERY: BUSINESS
# ABDUCTION: TO GAIN PECUNIARY BENEFIT (EXTORTION)
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# ASSAULT: MALICIOUS, VICTIM SEVERELY INJURED
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# UNLICENSED DOG
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# DWI: 1ST OFF, BAC .15-.20%
# RECKL/SPEED OVER 80 MPH
# MALICIOUS WOUNDING
# DRUGS: POSSESS SCH I OR II
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$500
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# ASSAULT: (MISDEMEANOR)
# RENT BY FRAUD: ANIMAL/AIRCRAFT/VEHICLE/BOAT
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING, OVER 80MPH
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 1 OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# BAILEE: VIOLATE CONDITION OF RELEASE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROTECTIVE ORDER: VIOLATION
# PROTECTIVE ORDER: VIOLATION
# PROTECTIVE ORDER: VIOLATION
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# ID THEFT:OBTN GOODS/SERVICE W/INTNT DEFRD>$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 2ND OFF W/IN 5Y - 10Y
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# GRAND LARCENY: $200+ NOT FROM A PERSON
# PHONE: DAMAGE LINE; PREVENT SUMMONING LAW ENF
# ASSAULT: ON FAMILY MEMBER
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RUNNING AT LARGE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# PUBLIC RECORDS: EMPLOY AS TRUE, FORGERY
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# LARCENY: THIRD OR SUBSEQUENT CONVICTION
# LARCENY: THIRD OR SUBSEQUENT CONVICTION
# PROTECTIVE ORDER: VIOLATION (FAMILY ABUSE)
# LICENSE: DRIVE W/O
# RECKL/SPEED OVER 80 MPH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# OTHER FORGERY WRITING: EMPLOY AS TRUE
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# RECKL/SPEED OVER 80 MPH
# LICENSE: DRIVE W/O, 2+ OFFENSE
# MONUMENT: INTENTIONAL DAMAGE, VALUE <$1000
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# TRAFFIC:FAIL TO OBEY TRAFFIC LIGHTS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# LICENSE: DRIVE W/O
# PROBATION VIOLATION-FELONY
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# INSUR: OPERATE UNINSURED VEH
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PHONE: DAMAGE LINE; PREVENT SUMMONING LAW ENF
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRIVE WHILE REVOKED-DWI
# LICENSE: DRIVE W/O
# ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$500
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 1ST OFF, BAC .15-.20%
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# ASSAULT: ON FAMILY MEMBER
# PHONE: DAMAGE LINE; PREVENT SUMMONING LAW ENF
# ASSAULT: ON FAMILY MEMBER
# RECKL/SPEED OVER 80 MPH
# RECKL/SPEED OVER 80 MPH
# THREAT: IN WRITING
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# DRIVE WHILE REVOKED-DWI
# UNLICENSED DOG
# FUGITIVE: ON FELONY W/O WARRANT-EXTRADITION
# PROBATION: VIOLATION ON FELONY OFFENSE
# RECK DR: SPEEDING 20MPH+
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# TITLE/REGIST/PLATES: FRAUD
# UNRESTRICTED DOG VIOL
# LICENSE: DRIVE W/O
# DWI: 1ST OFF, BAC .15-.20%
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/PWI MARIJUANA <1/2 OZ
# FUGITIVE: ARREST ON MISD CHARGE PER 19.2-99
# POSS OPEN ALCH CONT
# LICENSE: DRIVE W/O, 2+ OFFENSE
# ACCIDENT: DRIVER NOT RPT, W/DEATH/INJ/DAMAG>1000
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# DWI: 2ND OFF W/IN 5Y
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# None
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DISREG POLICE SIGNAL TO STOP,EL
# LICENSE: DRIVE W/O
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# BURGLARIOUS TOOLS: POSSESSION OF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS W/INTENT TO MANUF/SELL SCH I, II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# RESISTING ARREST
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# THROWING OR DEPOSITING CERTAIN SUBSTANCES UPON HIG
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# EMBEZZLEMENT: >=$200
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LICENSE: DRIVE W/O
# ALCH BEV TEND/DRK  IN PUBLIC
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# RECKLE/20 MPH OVER LIMIT
# UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY<200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# IDENTITY THEFT: POSSESS FICTITIOUS ID CARD
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ALCOHOL: PURCH/POSSESS BY PERSON <21Y
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# GRAND LARCENY: $5+ FROM A PERSON (PICK POCKET)
# PROBATION: VIOLATION ON FELONY OFFENSE
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# EXCESSIVE NOISE IN RESIDENTIAL DWELLING (GENERAL)
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200
# DWI: 2ND OFF W/IN 5Y
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$500
# CONCEALED WEAPON: CARRY
# RECKLE/20 MPH OVER LIMIT
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# TRESPASS-POSTED OR ADVISED TO LV
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PETIT LARCENY: <$200 NOT FROM A PERSON
# EMBEZZLEMENT: >=$200
# PROTECTIVE ORDER: VIOLATION
# RECKLE/20 MPH OVER LIMIT
# DRUGS: POSSESS SCH I OR II
# POSS OPEN ALCH CONT
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# RECK DR: SPEEDING 20MPH+
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FORGERY: OBTAIN SIGNATURE BY FALSE PRETENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: ON PARKING LOT/CLOSED HWY
# DRUGS: POSSESS SCH I OR II
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# RECK DR: SPEEDING 20MPH+
# RECK DR: SPEEDING 20MPH+
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# CONSPIRING: TO COMMIT LARCENY > $200
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PROSTITUTION: USE VEHICLE TO AID
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# PROSTITUTION: AID
# PROSTITUTION: RECEIVE EARNINGS (PANDERING)
# PROSTITUTION:RECEIVE MONEY TO PROCURE PROSTITUTE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROFANE SWEARING OR INTOXICATION IN PUBLIC
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DISORDERLY CONDUCT
# WEAR MASKS IN CERTAIN PLACES
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# ALCOHOL: DRINKING/OFFER DRINK IN PUBLIC PLACE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS SCH I OR II
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: DRUGS, 1ST OFFENSE
# DRUGS:DISTRIB/PWI,ACCOMMODATE ANOTHER,MARIJUANA
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RECK DR: SPEEDING, OVER 80MPH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 1ST OFFENSE
# FALSE IDENTIFY SELF TO LAW ENFORCEMENT
# FAILURE TO APPEAR: ON FELONY OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECKLE/20 MPH OVER LIMIT
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# DRUGS: POSSESS SCH I OR II
# ABDUCTION: BY FORCE, INTIMIDATION OR DECEPTION
# ASSAULT: (MISDEMEANOR)
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LARCENY: THIRD OR SUBSEQUENT CONVICTION
# PHONE: ANNOYING RINGING
# DWI: 1ST OFFENSE
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# PROBATION: VIOLATION ON FELONY OFFENSE
# LICENSE: DRIVE W/O
# TRESPASS-POSTED OR ADVISED TO LV
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# POSS OPEN ALCH CONT
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# VEH INSPECTION STICKER: MAKE/USE COUNTERFEIT
# INSUR: OPERATE UNINSURED VEH
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# DISREG POLICE SIGNAL TO STOP,EL
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O, 2+ OFFENSE
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING, OVER 80MPH
# LICENSE: DRIVE W/O
# FAIL TO STOP FOR POLICE: ATT TO ESCAPE/ELUDE
# RECKLE/20 MPH OVER LIMIT
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY
# LICENSE: DRIVE W/O
# ALCOHOL: DRINKING/OFFER DRINK IN PUBLIC PLACE
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# INSUR: OPERATE UNINSURED VEH
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FIREARM: POSSESS BY NON VIOLENT FELON, >10 YRS
# UNVACCINATED DOG OR CAT
# UNLICENSED DOG
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# PROBATION: VIOLATION ON MISDEMEANOR OFFENSE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O, 2+ OFFENSE
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# PROBATION: VIOLATION ON FELONY OFFENSE
# PROBATION: VIOLATION ON FELONY OFFENSE
# PROBATION: VIOLATION ON FELONY OFFENSE
# PROBATION: VIOLATION ON FELONY OFFENSE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# OPERATE VEHICLE WITH SUN-SHADING/TINTING FILMS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# EMERGENCY SERVICES: CALL/SET ALARM W/O CAUSE
# LICENSE: DRIVE W/O
# UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY<200
# CREDIT CARD FORGERY DEVICES: POSSESS
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# DWI: 1ST OFFENSE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# ASSAULT: (MISDEMEANOR)
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# RECK DR: SPEEDING, 20MPH+ OVER POSTED <=30MPH
# DRUGS: POSSESS SCH I OR II
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# LARCENY: SECOND CONVICTION
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# ABDUCTION: BY FORCE, INTIMIDATION OR DECEPTION
# ASSAULT: ON FAMILY MEMBER
# LABOR/CUSTODY: ENDANGER/CRUELLY TREAT CHILD
# PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG
# PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG
# PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG
# PROTECTIVE ORDER: VIOLATION
# ...
# CREDIT CARD FORGERY
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# IDENTITY THEFT: OBTAIN ID TO DEFRAUD
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# None
# ASSAULT: ON FAMILY MEMBER
# DWI: 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# ALCOHOL: PURCH/POSSESS BY PERSON <21Y
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DWI: 1ST OFF, BAC .15-.20%
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RECK DR: SPEEDING 20MPH+
# PROBATION VIOLATION-FELONY
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DWI: 2ND OFF W/IN 5Y, BAC >.20%
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: (MISDEMEANOR)
# UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY<200
# LIC REVOKED: DR W/O LICENSE, 3+ OFF > 10 YRS
# TRESPASS-POSTED OR ADVISED TO LV
# DUMPING TRASH, COMP ANIMAL, ETC ON HIWAY, PROPERTY
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RECK DR: SPEEDING 20MPH+
# DWI: 1ST OFFENSE
# DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FIREARM: RECKLESS HANDLING
# GRAND LARCENY: AUTO THEFT
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# LICENSE: DRIVE W/O
# GRAND LARCENY: $200+ NOT FROM A PERSON
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# ASSAULT: ON FAMILY MEMBER
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200
# OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170
# FUGITIVE: ON FELONY W/O WARRANT-EXTRADITION
# LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 2+OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# STOLEN GOODS: BUY/RECEIVE, LARCENY <$200
# LARCENY: THIRD OR SUBSEQUENT CONVICTION
# PETIT LARCENY: <$200 NOT FROM A PERSON
# UNVACCINATED DOG OR CAT
# UNLICENSED DOG
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: POSSESS SCH I OR II
# PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# TRESPASS-POSTED OR ADVISED TO LV
# ENTER A SCHOOL AFT CONVICTED OF SEX OFFENSE
# DWI: 1ST OFFENSE
# DRIVE WHILE REVOKED-DWI
# DRIVING AFTER FORFEITURE OF LICENSE
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# RECK DR: ON PARKING LOT/CLOSED HWY
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD FORGERY
# CREDIT CARD FORGERY
# CREDIT CARD FORGERY
# CREDIT CARD FRAUD: BY PERSON>=$200 IN 6M
# CREDIT CARD FRAUD: RECEIVE GOODS >=$200 IN 6M
# OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF
# OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF
# OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF
# OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF
# OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF
# OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF
# <15Y TO PERFORM PORN, OFFENDR 7+ YRS OLDER, 2ND
# PROPOSE SEX BY COMP  <15 OFFENDR 7+ YR, 2ND OFF
# PROPOSE SEX BY COMP  <15 OFFENDR 7+ YR, 2ND OFF
# PROPOSE SEX BY COMP  <15 OFFENDR 7+ YR, 2ND OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# ASSAULT: (MISDEMEANOR)
# ASSAULT: ON FAMILY MEMBER
# MALICIOUS WOUNDING
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# MASSAGE THERAPIST LICENSE REQUIRED
# DWI: 1ST OFFENSE
# DRIVE WHILE REVOKED-DWI
# ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000
# PROSTITUTION
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: ON FAMILY MEMBER
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS SCH IV
# ASSAULT: ON FAMILY MEMBER
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# PETIT LARCENY: <$200 NOT FROM A PERSON
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# LARCENY: THIRD OR SUBSEQUENT CONVICTION
# DRUNK IN PUBLIC OR PROFANE
# ASSAULT: ON FAMILY MEMBER
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# ASSAULT: ON FAMILY MEMBER
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# FIREARM: POSSESSION W/ SCH I OR II DRUG
# DRUGS: POSSESS SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: POSSESS W/INTENT TO MANUF/SELL SCH I, II
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING 20MPH+
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# TRESPASS: AFTER BEING FORBIDDEN TO DO SO
# EMBEZZLEMENT: >=$200
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: SPEEDING 20MPH+
# ASSAULT: ON FAMILY MEMBER
# INSUR: OPERATE UNINSURED VEH
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LICENSE: DRIVE W/O
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# CONSPIRING: TO COMMIT LARCENY > $200
# RECKLE/20 MPH OVER LIMIT
# DWI: DRUGS, 1ST OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PAROLE VIOLATION-FELONY
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: NOT STOP FOR SCH BUS + REV LIC & DEATH
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUNK IN PUBLIC OR PROFANE
# CREDIT CARD LARCENY: TAKE/OBTAIN NO.
# CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PETIT LARCENY: <$5 FROM A PERSON (PICK POCKET)
# PETIT LARCENY: <$5 FROM A PERSON (PICK POCKET)
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRIVE WHILE REVOKED-DWI
# DWI: 3RD OFF W/IN 5Y - 10Y
# LICENSE: DRIVE W/O
# FUGITIVE: ARREST ON FELONY CHARGE PER 19.2-99
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# ALCH BEV TEND/DRK  IN PUBLIC
# LICENSE: DRIVE W/O
# VEH WINDOWS: APPLY SUN-SHADING UNLAWFULLY, 1 OFF
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: DISTRIB/PWI MARIJUANA <1/2 OZ
# DRUGS: POSSESS W/INTENT TO MANUF/SELL SCH I, II
# INSUR: OPERATE UNINSURED VEH
# TITLE: POSSESS TITLE ISSUED TO ANOTHER
# DRUGS: POSSESS SCH I OR II
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: ON FAMILY MEMBER
# LICENSE: DRIVE W/O
# LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS
# DWI: 1ST OFFENSE
# RECK DR: DR TOO FAST FOR HWY CONDITIONS
# DRUNK IN PUBLIC OR PROFANE
# GRAND LARCENY: $200+ NOT FROM A PERSON
# BURGLARIOUS TOOLS: POSSESSION OF
# UNRESTRICTED DOG VIOL
# LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# INSUR: OPERATE UNINSURED VEH
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS SCH I OR II
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200
# PETIT LARCENY: <$200 NOT FROM A PERSON
# OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUNK IN PUBLIC OR PROFANE
# DRIVING AFTER FORFEITURE OF LICENSE
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRIVE WHILE REVOKED-DWI
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# COMMUNITY DIVERSION: VIOLATION ON MISDEMEANOR
# LICENSE: DRIVE W/O
# DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY
# DRUNK IN PUBLIC OR PROFANE
# DRUNK IN PUBLIC OR PROFANE
# RECK DR: GENERALLY + REV LIC & CAUSE DEATH
# RECKLE/20 MPH OVER LIMIT
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS
# RECK DR: SPEEDING 20MPH+
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRIVE WHILE REVOKED-DWI
# POSS OPEN ALCH CONT
# POSS OPEN ALCH CONT
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# MONUMENT: INTENTIONAL DAMAGE, VALUE >=$1000
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O
# ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000
# LICENSE: DRIVE W/O
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRIVE WHILE REVOKED-DWI
# LICENSE: DRIVE W/O
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUNK IN PUBLIC OR PROFANE
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUNK IN PUBLIC OR PROFANE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: ON FAMILY MEMBER
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# DRUNK IN PUBLIC OR PROFANE
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: (MISDEMEANOR)
# LICENSE: DRIVE W/O
# LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER
# POSS OPEN ALCH CONT
# LICENSE: DRIVE W/O
# INSUR: OPERATE UNINSURED VEH
# LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RECK DR: SPEEDING 20MPH+
# DRUGS: POSSESS SCH I OR II
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# PUBLIC RECORDS: EMPLOY AS TRUE, FORGERY
# PUBLIC RECORDS: FORGERY
# LICENSE: DRIVE W/O
# BAILEE: VIOLATE CONDITION OF RELEASE
# PROTECTIVE ORDER: VIOLATION
# ASSAULT: ON FAMILY MEMBER
# PHONE: INJURE/TAP LINE; COPY/OBSTRUCT MESSAGE
# RUNNING AT LARGE
# GRAND LARCENY: $5+ FROM A PERSON (PICK POCKET)
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# STOLEN PROPERTY: SELL/ETC, LARCENY >=$200
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# DOG: FAIL TO CONTROL/RESULTS IN SERIOUS INJURY
# FALSE STATEMENTS: HOUSING AID
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: SPEEDING 20MPH+
# ASSAULT: (MISDEMEANOR)
# RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS
# None
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ACCIDENT: DRIVER NOT RPT, W/DEATH/INJURY
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# INSUR: OPERATE UNINSURED VEH
# STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200
# FORGERY: OBTAIN SIGNATURE BY FALSE PRETENSE
# DRUGS: POSSESS MARIJUANA, 2+ OFF
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECKL/SPEED OVER 80 MPH
# RECKLE/20 MPH OVER LIMIT
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# RECKLE/20 MPH OVER LIMIT
# DRUNK IN PUBLIC OR PROFANE
# TRESPASS SCH FORBIDDEN
# PETIT LARCENY: <$200 NOT FROM A PERSON
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: (MISDEMEANOR)
# FIREARM/ETC: POINTING/BRANDISHING
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# ASSAULT: (MISDEMEANOR)
# ASSAULT: (MISDEMEANOR)
# DISREG POLICE SIGNAL TO STOP,EL
# DRUNK IN PUBLIC OR PROFANE
# STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200
# GRAND LARCENY: $200+ NOT FROM A PERSON
# DRUNK IN PUBLIC OR PROFANE
# EXCESSIVE NOISE IN RESIDENTIAL DWELLING (GENERAL)
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LARCENY - SHOPLIFTING
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# ASSAULT: (MISDEMEANOR)
# DRUNK IN PUBLIC OR PROFANE
# ASSAULT: (MISDEMEANOR)
# BAILEE: VIOLATE CONDITION OF RELEASE
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: (MISDEMEANOR)
# ENTER PROPERTY TO DAMAGE, ETC.:
# VEHICLE/AIRCRAFT/BOAT/ETC: DESTROY/INJURE
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# ASSAULT: ON FAMILY MEMBER
# ASSAULT: ON FAMILY MEMBER
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# GRAND LARCENY: $200+ NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# FUGITIVE: ON FELONY W/O WARRANT-EXTRADITION
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# INSUR: OPERATE UNINSURED VEH
# LICENSE: DRIVE W/O
# SHOPLIFT/ALTER PRICE: LARCENY <$200
# INSUR: OPERATE UNINSURED VEH
# DRUGS: POSSESS MARIJUANA, 1ST OFF
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# LICENSE: DRIVE W/O
# PETIT LARCENY: <$200 NOT FROM A PERSON
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LAW ENF COMMAND: DISREGARD OR ELUDE, ENDANGER
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# DWI: DRUGS, 1ST OFFENSE
# LICENSE: DRIVE W/O
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUNK IN PUBLIC OR PROFANE
# LICENSE: DRIVE W/O
# PLATES/DECALS: POSSESS/FORGED
# TRESPASS: AFTER BEING FORBIDDEN TO DO SO
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# DRUGS: POSSESS SCH I OR II
# DRUGS: POSSESS SCH I OR II
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# None
# GRAND LARCENY: AUTO THEFT
# TITLE/SALVAGE: OBTAIN/CREATE FALSE DOCS, FRAUD
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# OPERATE VEHICLE WITH SUN-SHADING/TINTING FILMS
# DISORDERLY CONDUCT
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE
# ASSAULT: (MISDEMEANOR)
# STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY
# FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS
# LIC REVOKED: DR W/O LICENSE, 2 OFF
# DWI: 1ST OFFENSE
# LICENSE: DRIVE W/O
# PRESCRIPTIONS: OBTAIN BY FRAUD/FORGERY/ETC
# PRESCRIPTIONS: OBTAIN BY FRAUD/FORGERY/ETC
# PRESCRIPTIONS: OBTAIN BY FRAUD/FORGERY/ETC
# PRESCRIPTIONS: OBTAIN BY FRAUD/FORGERY/ETC
# LICENSE: DRIVE W/O, 2+ OFFENSE
# RECKLE/20 MPH OVER LIMIT
# LICENSE: DRIVE W/O
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# DRINKING WHILE DRIVING OR OPEN CONTAINER
# VEH DEALER: UNLAWFUL USE OF DEALER PLATES
# DRUGS: POSSESS SCH I OR II
# DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# LICENSE: DRIVE W/O
# DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY
# ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON
# IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.
# OBSTRUCT JUSTICE: W/O THREATS/FORCE
# FALSE REPORT: FALSELY SUMMON/REPORT TO LAW ENF
# TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS
# DRUNK IN PUBLIC OR PROFANE
# TRAFFIC:EXPIRED TEMPORARY REGISTRATION
# LIC REVOKED: DR W/O LICENSE, 1 OFF
# LICENSE: DRIVE W/O, 2+ OFFENSE
# LICENSE: DRIVE W/O
# ASSAULT: ON FAMILY MEMBER

# %%
import agate
arrests = agate.Table.from_csv('arrest.csv')
charges = arrests.group_by('Charge Descrip')
ages_median = charges.aggregate([('ages_median', agate.Median('Age'))])
ages_median.print_table(max_column_width=50)
# Out:
# |-----------------------------------------------------+--------------|
# |  Charge Descrip                                     | ages_median  |
# |-----------------------------------------------------+--------------|
# |  PETIT LARCENY: <$200 NOT FROM A PERSON             |        27.0  |
# |  LICENSE: DRIVE W/O                                 |        30.0  |
# |  LICENSE: DRIVE W/O, 2+ OFFENSE                     |        28.0  |
# |  GRAND LARCENY: $200+ NOT FROM A PERSON             |        29.0  |
# |  BURGLARIOUS TOOLS: POSSESSION OF                   |        31.0  |
# |  IDENTITY THEFT: OBTAIN ID TO DEFRAUD               |        19.0  |
# |  DRUGS: POSSESS MARIJUANA, 1ST OFF                  |        23.0  |
# |  LIC REVOKED: DR W/O LICENSE, 2 OFF                 |        30.0  |
# |  LIC REVOKED: DR W/O LICENSE, 1 OFF                 |        30.0  |
# |  RECKLE/20 MPH OVER LIMIT                           |        27.5  |
# |  DRUNK IN PUBLIC OR PROFANE                         |        32.0  |
# |  TRESPASS: AFTER BEING FORBIDDEN TO DO SO           |        38.0  |
# |  FAILURE TO APPEAR: ON FELONY OFFENSE               |        27.0  |
# |  IDENTITY THEFT: OBTAIN ID TO AVOID ARREST/ETC.     |        21.5  |
# |  DRUGS: POSSESS SCH I OR II                         |        29.0  |
# |  DRUGS: DISTRIB/PWI MARIJUANA >1/2 OZ TO 5 LBS      |        24.0  |
# |  PARAPHERNALIA: UNAUTHORIZED DISTRIBUTION OF        |        31.0  |
# |  INSUR: OPERATE UNINSURED VEH                       |        30.0  |
# |  ASSAULT: ON FAMILY MEMBER                          |        33.5  |
# |  PHONE: INJURE/TAP LINE; COPY/OBSTRUCT MESSAGE      |        30.5  |
# |  ACCIDENT: DRIVER NOT REPORT, W/ DAMAGE <$1000      |        42.0  |
# |  STRANGULATION:RESULTS IN WOUNDING/BODILY INJURY    |        32.0  |
# |  POSS OPEN ALCH CONT                                |        34.0  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$250   |        25.0  |
# |  RECK DR: DR TOO FAST FOR HWY CONDITIONS            |        27.0  |
# |  IMPROPER USE OF DEALER TAGS                        |        37.5  |
# |  DWI: 1ST OFFENSE                                   |        31.0  |
# |  RECKL/SPEED OVER 80 MPH                            |        27.0  |
# |  RECK DR: SPEEDING 20MPH+                           |        31.0  |
# |  DISREG POLICE SIGNAL TO STOP,EL                    |        25.5  |
# |  FAILURE TO APPEAR: ON MISDEMEANOR OFFENSE          |        27.5  |
# |  OPERATE VEHICLE WITH SUN-SHADING/TINTING FILMS     |        29.0  |
# |  RECK DR: GENERALLY, ENDANGER LIFE/LIMB/PROPERTY    |        29.0  |
# |  MALICIOUS BODILY INJURY                            |        31.0  |
# |  RECK DR: SPEEDING, DR 60MPH ON POSTED 35MPH        |        32.0  |
# |  MALICIOUS WOUNDING                                 |        22.5  |
# |  RUNNING AT LARGE                                   |        39.5  |
# |  NOISE PROHIBITIONS: SOUND AMPLIFICATION DEVICE (11 |        36.0  |
# |  PROBATION: VIOLATION ON FELONY OFFENSE             |        35.0  |
# |  LIC REVOKED: DR W/O LICENSE, 3+ OFF W/IN 10 YRS    |        27.0  |
# |  DRUGS: POSSESS MARIJUANA, 2+ OFF                   |        23.0  |
# |  DRINKING WHILE DRIVING OR OPEN CONTAINER           |        25.5  |
# |  DWI: 2ND OFF W/IN 5Y                               |        38.0  |
# |  OBSTRUCT JUSTICE: W/ THREATS/FORCE                 |        32.0  |
# |  DWI: REFUSAL OF BLOOD OR BREATH TEST, 1 OFF        |        31.0  |
# |  LIC REVOKED: ALLOW ANOTHER W/ SUSP/REV LIC TO DR   |        42.0  |
# |  BAIL/PRETRIAL SERVICES VIOLATION-MISD. FTA         |        19.0  |
# |  LEARNER`S PERMIT LIC: VIOLATE RESTRICTIONS         |        20.0  |
# |  SHOPLIFT/ALTER PRICE: LARCENY <$200                |        28.0  |
# |  GRAND LARCENY: AUTO THEFT                          |        20.0  |
# |  DWI: PERSON <21Y DRIVING W/ BAC .02% TO .07%       |        18.0  |
# |  ENTER PROPERTY TO DAMAGE, ETC.:                    |        19.5  |
# |  UNLICENSED DOG                                     |        45.5  |
# |  EMBEZZLEMENT: <$200                                |        21.5  |
# |  UNVACCINATED DOG OR CAT                            |        47.0  |
# |  DWI: 1ST OFF, BAC .15-.20%                         |        28.0  |
# |  MONUMENT: INTENTIONAL DAMAGE, VALUE <$1000         |        24.0  |
# |  BAD CHECK: LARCENY <$200                           |        47.0  |
# |  OBSTRUCT JUSTICE:FALSE INFO TO CRIM INVESTIGATOR   |        21.0  |
# |  FALSE IDENTIFY SELF TO LAW ENFORCEMENT             |        30.0  |
# |  RECK DR: NOT STOP FOR SCH BUS W/ FLASHING LIGHTS   |        37.0  |
# |  DRUGS: POSSESS SCH IV                              |        22.0  |
# |  ORDER: VIOLATION OF J&DR COURT ORDER               |        49.0  |
# |  ASSAULT: (MISDEMEANOR)                             |        28.0  |
# |  DRUGS: POSSESS W/INTENT TO MANUF/SELL SCH I, II    |        22.5  |
# |  DRUGS: POSSESS SCH III                             |        30.0  |
# |  INSUR:GIVE FALSE VEH INSUR INFO OR NOT SURRENDER   |        20.0  |
# |  COMMUNITY DIVERSION: VIOLATION ON MISDEMEANOR      |        23.5  |
# |  DWI: 2ND OFF W/IN 5Y - 10Y                         |        34.0  |
# |  DWI: REFUSAL OF BLOOD OR BREATH TEST, 2 OFF        |        30.0  |
# |  DRIVING WHILE OPERATORS LICENSE SUSPENDED OR REVOK |        27.0  |
# |  TRESPASS-POSTED OR ADVISED TO LV                   |        31.0  |
# |  LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 1 OFF   |        29.0  |
# |  TRAFFIC:FAIL TO OBEY TRAFFIC LIGHTS                |        30.0  |
# |  STALKING: VIOLATION OF PROTECTIVE ORDER            |        37.0  |
# |  STOLEN PROPERTY: W/ INTENT TO SELL, LARCENY>=$200  |        29.0  |
# |  COMMER LIC: DR VEH W/O REQUIRED LIC ENDORSEMENTS   |        37.0  |
# |  DISORDERLY CONDUCT                                 |        34.5  |
# |  ASSAULT: ON LAW ENF/JUDGE/DOC/FIRE/EMERG PERSON    |        29.0  |
# |  ANIMAL:INADEQUATE CARE OF ANIMAL(S) BY OWNER       |        30.0  |
# |  PROFANE SWEARING OR INTOXICATION IN PUBLIC         |        31.0  |
# |  FIREARM/ETC: POINTING/BRANDISHING                  |        28.0  |
# |  DRIVE WHILE REVOKED-DWI                            |        35.0  |
# |  VEH DEALER: UNLAWFUL USE OF DEALER PLATES          |        36.0  |
# |  CONTRIBUTE TO DELINQUENCY OF MINOR                 |        22.0  |
# |  COUNTY HACKERS` LICENSE REQUIRED                   |        30.0  |
# |  OPERATOR LIC REQUIRED FOR TAXI DRV                 |        30.0  |
# |  TITLE/REGIST/PLATES: DISPLAY ALTERED/FICTITIOUS    |        35.5  |
# |  PROBATION VIOLATION-FELONY                         |        27.0  |
# |  PROBATION VIOLATION-MISDEMEANOR                    |        27.0  |
# |  PROBATION: VIOLATION ON MISDEMEANOR OFFENSE        |        22.0  |
# |  GRAND LARCENY: $5+ FROM A PERSON (PICK POCKET)     |        27.5  |
# |  BURGLARY: ENTER BLDG TO COMMIT LARCENY/A&B/ETC     |        22.0  |
# |  ABUSE/NEGLECT CHILD: RECKLESS DISREGARD FOR LIFE   |        31.0  |
# |  STOLEN GOODS: BUY/RECEIVE, LARCENY <$200           |        31.0  |
# |  COMMER LIC: DR COMMERCIAL VEH W/O VALID LICENSE    |        29.5  |
# |  RESISTING ARREST                                   |        31.0  |
# |  COMMUNITY-BASED PROBATION: VIOLATION ON MISD OFF   |        27.0  |
# |  PHONE/CITIZENS BAND: USE PROFANE/THREATEN LANG     |        26.0  |
# |  RESTRICTED LIC: VIOLATE RESTRICTIONS               |        44.0  |
# |  ALCOHOL: PURCH/POSSESS BY PERSON <21Y              |        19.0  |
# |  IDENTITY THEFT: POSSESS FICTITIOUS ID CARD         |        19.0  |
# |  EMBEZZLEMENT: >=$200                               |        24.0  |
# |  OBSTRUCT JUSTICE: W/O THREATS/FORCE                |        27.0  |
# |  STOLEN GOODS: BUY/RECEIVE, LARCENY >=$200          |        36.0  |
# |  SHOPLIFT/ALTER PRICE: LARCENY >=$200               |        23.0  |
# |  CREDIT CARD FRAUD: BY PERSON, <$200 IN 6M          |        29.0  |
# |  CREDIT CARD LARCENY: TAKE/OBTAIN NO.               |        25.0  |
# |  MALIC SHOOT OR THROW MISSILE IN/AT OCC. BLDG       |        52.0  |
# |  MONUMENT: INTENTIONAL DAMAGE, VALUE >=$1000        |        46.5  |
# |  VEH INSPECTION STICKER: UNAUTHORIZED POSSESSION    |        42.0  |
# |  WEAR MASKS IN CERTAIN PLACES                       |        31.0  |
# |  DISARM: LAW ENF/DOC OF FIREARM OR STUN-GUN         |        31.0  |
# |  BURGLARY: ENTER HOUSE TO COMMIT LARCENY/A&B/ETC    |        34.0  |
# |  PLATES/DECALS: POSSESS/FORGED                      |        36.0  |
# |  FORGERY: OBTAIN SIGNATURE BY FALSE PRETENSE        |        25.5  |
# |  CONTEMPT OF COURT: FAIL TO APPEAR CAPIAS           |        29.0  |
# |  BAILEE: VIOLATE CONDITION OF RELEASE               |        32.5  |
# |  THROWING OR DEPOSITING CERTAIN SUBSTANCES UPON HIG |        28.0  |
# |  DRUGS: MANUFACTURE, SCH I OR II                    |        51.0  |
# |  CONCEALED WEAPON: CARRY                            |        21.5  |
# |  PUBLIC RECORDS: FORGERY                            |        29.0  |
# |  CREDIT CARD FORGERY DEVICES: POSSESS               |        27.0  |
# |  RECK DR: SPEEDING, OVER 80MPH                      |        28.0  |
# |  SEXUAL BATTERY: > 1 OCCASION OR >1 WITNESS         |        37.0  |
# |                                                     |        32.0  |
# |  Z-IMPROPER REGISTRATION                            |        31.0  |
# |  VEHICLE/AIRCRAFT/BOAT/ETC: DESTROY/INJURE          |        25.0  |
# |  OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY<$200     |        30.0  |
# |  MONUMENT: UNLAWFUL DAMAGE, NO INTENT TO STEAL      |        22.5  |
# |  PROSTITUTION: KEEP/RESIDE IN BAWDY PLACE           |        28.0  |
# |  RECK DR: LOAD/PASSENGERS INTERFERE W/ CONTROL      |        37.0  |
# |  CREDIT CARD FRAUD: BY PERSON>=$200 IN 6M           |        25.0  |
# |  UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY>200   |        35.0  |
# |  DWI: 2ND OFF W/IN 10Y, BAC .15-.20%                |        34.5  |
# |  PHONE: ANNOYING RINGING                            |        55.0  |
# |  WELFARE FRAUD: LARCENY >=$200                      |        45.0  |
# |  AGGRAVATED SEXUAL BATTERY: TYPE NOT CLEAR          |        32.0  |
# |  MASSAGE THERAPIST LICENSE REQUIRED                 |        22.0  |
# |  DWI: 3RD OFF W/IN 5Y - 10Y                         |        37.5  |
# |  PROTECTIVE ORDER: VIOLATION                        |        36.0  |
# |  DRUGS: DISTRIB/PWI MARIJUANA <1/2 OZ               |        20.5  |
# |  DRUGS: DISTRIB/SELL FOR PROFIT SCH I OR II         |        25.0  |
# |  OBTAIN MONEY/ETC: FALSE PRETENSE, LARCENY>=$200    |        29.5  |
# |  OTHER FORGERY WRITING:NOT IN 18.2-168 & 18.2-170   |        32.0  |
# |  EMERG VEH: NOT APPROACH STOPPED VEH W/ CAUTION >=2 |        47.0  |
# |  RECK DR: ON PARKING LOT/CLOSED HWY                 |        20.0  |
# |  RAPE, FORCIBLE - TYPE NOT CLEAR FROM RECORD        |        27.0  |
# |  ABDUCTION: BY FORCE, INTIMIDATION OR DECEPTION     |        28.0  |
# |  ASSAULT: BY INMATE, PROBATIONER, ETC ON EMPLOYEE   |        28.0  |
# |  TRAFFIC:EXPIRED TEMPORARY REGISTRATION             |        32.0  |
# |  DUMPING: DUMP TRASH/ETC ON HWY/PRIVATE PROPERTY    |        23.0  |
# |  SPEC LIC: DR BUS/CYCLE/COMM VEH W/O ENDORSEMENT    |        25.0  |
# |  VIOLATION OF VA STATE PARK REGULATIONS             |        26.0  |
# |  INDECENT EXPOSURE                                  |        37.0  |
# |  LICENSE: ALLOW PERSON W/NO LEGAL RIGHT TO DR VEH   |        35.0  |
# |  ROBBERY: RESIDENCE                                 |        20.0  |
# |  MOB: MALICIOUS WOUNDING                            |        20.0  |
# |  ROBBERY: ON OR NEAR STREET                         |        24.0  |
# |  LICENSES REQUIRED                                  |        39.0  |
# |  VEHICLE/AIRCRAFT/BOAT/ETC: ENTER/SET IN MOTION     |        28.5  |
# |  BOMB/BURN THREAT: ACCUSED >=15Y                    |        41.5  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$500   |        25.0  |
# |  FIREARM: USE IN COMMISSION OF FELONY, 1ST OFF      |        30.5  |
# |  ROBBERY: STREET W/ USE OF GUN OR SIMULATED GUN     |        30.5  |
# |  PROSTITUTION                                       |        25.0  |
# |  RECK DR: GENERALLY + REV LIC & CAUSE DEATH         |        26.5  |
# |  TRESPASS SCH FORBIDDEN                             |        36.0  |
# |  DOG: NOT OBTAIN DANGER DOG REGSTRAT'N CERTIFICAT   |        42.0  |
# |  ADULTERY/FORNICATION: INCEST W/ CHILD 13 - 17Y     |        39.0  |
# |  PETIT LARCENY: <$5 FROM A PERSON (PICK POCKET)     |        31.5  |
# |  STOLEN GOODS:REC. GOODS USED IN INVSTGATN>=$200    |        21.0  |
# |  MARIJUANA SYNTHETIC:POSSES CANNABIMIMETIC AGENT    |        35.5  |
# |  PEEP/SPY INTO DWELLING: THROUGH PEEPHOLE           |        37.0  |
# |  PEEP/SPY INTO DWELLING: THROUGH WINDOW/DOOR        |        37.0  |
# |  MASSAGE PERMIT REQUIRED                            |        36.5  |
# |  CREDIT CARD FORGERY                                |        22.0  |
# |  DRUGS: MANUF/DISTRIBUTE ON CERTAIN PROPERTIES      |        21.0  |
# |  PRELIMINARY PROTECTIVE ORDER: VIOLATION            |        39.0  |
# |  ARSON: DWELLING USUALLY OCCUPIED                   |        39.0  |
# |  DOG: ORDINANCE-DANGEROUS DOG VIOLATION             |        44.0  |
# |  ROBBERY: BUSINESS                                  |        21.0  |
# |  ABDUCTION: TO GAIN PECUNIARY BENEFIT (EXTORTION)   |        26.5  |
# |  ASSAULT: MALICIOUS, VICTIM SEVERELY INJURED        |        21.0  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG<$500   |        23.0  |
# |  RENT BY FRAUD: ANIMAL/AIRCRAFT/VEHICLE/BOAT        |        22.0  |
# |  ID THEFT:OBTN GOODS/SERVICE W/INTNT DEFRD>$200     |        24.0  |
# |  PHONE: DAMAGE LINE; PREVENT SUMMONING LAW ENF      |        37.0  |
# |  PUBLIC RECORDS: EMPLOY AS TRUE, FORGERY            |        26.0  |
# |  LARCENY: THIRD OR SUBSEQUENT CONVICTION            |        51.0  |
# |  PROTECTIVE ORDER: VIOLATION (FAMILY ABUSE)         |        23.0  |
# |  OTHER FORGERY WRITING: EMPLOY AS TRUE              |        27.0  |
# |  THREAT: IN WRITING                                 |        29.5  |
# |  FUGITIVE: ON FELONY W/O WARRANT-EXTRADITION        |        28.0  |
# |  TITLE/REGIST/PLATES: FRAUD                         |        34.0  |
# |  UNRESTRICTED DOG VIOL                              |        46.0  |
# |  FUGITIVE: ARREST ON MISD CHARGE PER 19.2-99        |        30.0  |
# |  ACCIDENT: DRIVER NOT RPT, W/DEATH/INJ/DAMAG>1000   |        36.0  |
# |  ALCH BEV TEND/DRK  IN PUBLIC                       |        50.0  |
# |  UNAUTHORIZED USE: ANIMAL/VEHICLE/ETC,LARCENY<200   |        30.0  |
# |  EXCESSIVE NOISE IN RESIDENTIAL DWELLING (GENERAL)  |        40.0  |
# |  CONSPIRING: TO COMMIT LARCENY > $200               |        33.0  |
# |  PROSTITUTION: USE VEHICLE TO AID                   |        27.0  |
# |  PROSTITUTION: AID                                  |        24.0  |
# |  PROSTITUTION: RECEIVE EARNINGS (PANDERING)         |        33.0  |
# |  PROSTITUTION:RECEIVE MONEY TO PROCURE PROSTITUTE   |        24.0  |
# |  ALCOHOL: DRINKING/OFFER DRINK IN PUBLIC PLACE      |        23.0  |
# |  DWI: DRUGS, 1ST OFFENSE                            |        23.0  |
# |  DRUGS:DISTRIB/PWI,ACCOMMODATE ANOTHER,MARIJUANA    |        22.0  |
# |  VEH INSPECTION STICKER: MAKE/USE COUNTERFEIT       |        22.0  |
# |  FAIL TO STOP FOR POLICE: ATT TO ESCAPE/ELUDE       |        19.0  |
# |  FIREARM: POSSESS BY NON VIOLENT FELON, >10 YRS     |        57.0  |
# |  EMERGENCY SERVICES: CALL/SET ALARM W/O CAUSE       |        54.5  |
# |  RECK DR: SPEEDING, 20MPH+ OVER POSTED <=30MPH      |        21.5  |
# |  LARCENY: SECOND CONVICTION                         |        25.0  |
# |  LABOR/CUSTODY: ENDANGER/CRUELLY TREAT CHILD        |        26.0  |
# |  DRUGS: MARIJUANA, MANUFACTURE FOR OTHERS           |        27.0  |
# |  DWI: REFUSAL OF TEST, 1 OFF                        |        26.0  |
# |  BLDG CODE: UNSAFE DWELLING 1ST VIOL (ORDINANCE)    |        44.0  |
# |  STALKING: REASONABLE FEAR OF DEATH/ASSAULT/ETC     |        42.0  |
# |  PRESCRIPTIONS: OBTAIN BY FRAUD/FORGERY/ETC         |        31.0  |
# |  OBSTRUCT JUSTICE: RESIST ARREST BY THREATS/FORCE   |        40.0  |
# |  WEAPON: POSSESS BY FELON (NOT FIREARM)             |        23.0  |
# |  RECK DR: NOT STOP BEFORE ENTERING HWY              |        18.0  |
# |  CONCEALED WEAPON: CARRY, 2 OFF                     |        28.0  |
# |  DRUGS: DISTRIB/PWI MARIJUANA >5 LBS                |        21.0  |
# |  BANK NOTES: FORGERY <10, OR EMPLOY AS TRUE         |        27.0  |
# |  COMMUNITY DIVERSION: VIOLATION ON FELONY OFF       |        30.0  |
# |  MONEY LAUNDERING: CONDUCT FINANCIAL TRANSACTION    |        48.0  |
# |  DRUG PARAPHERNALIA: SELL/POSSESS TO SELL           |        28.0  |
# |  LIC REVOKED: DR W/O LICENSE, 3+ OFF > 10 YRS       |        26.0  |
# |  TRESPASS: POST UNAUTHORIZED "NO TRESPASS" SIGNS    |        45.0  |
# |  DUMPING TRASH, COMP ANIMAL, ETC ON HIWAY, PROPERTY |        27.0  |
# |  FIREARM: RECEIVE STOLEN OR AID IN CONCEALING       |        19.0  |
# |  DWI: 3RD OFF W/IN 5Y                               |        28.0  |
# |  DRUGS: SELL/DISTRIB SCH III DRUG - NOT STEROID     |        19.0  |
# |  FIREARM: POSSESS BY FELON NONVIOLENT W/IN 10 YRS   |        20.5  |
# |  DWI: 1ST OFF, BAC >.20%                            |        57.5  |
# |  ORDER: NOT COMPLY W/ J&DR COURT ORDER              |        45.5  |
# |  FALSE REPORT: FALSELY SUMMON/REPORT TO LAW ENF     |        32.0  |
# |  CREDIT CARD APPLICATION: FALSE STMT, FRAUD         |        19.0  |
# |  FAIL TO APPEAR ON TRAFFIC SUMMONS                  |        28.0  |
# |  ASSAULT: ON FAMILY MEMBER, 3RD+ OFFENSE            |        23.0  |
# |  STOLEN PROPERTY: SELL/ETC, LARCENY >=$200          |        29.5  |
# |  OBJECT SEXUAL PENETRATION: TYPE NOT CLEAR          |        32.0  |
# |  SODOMY, FORCIBLE - TYPE NOT CLEAR FROM RECORD      |        25.0  |
# |  FIREARM: POSSESS BY FELON W/ VIOLENT OFFENSE       |        41.0  |
# |  PROTECTIVE ORDER                                   |        25.0  |
# |  CONTEMPT OF COURT: J&DR COURT                      |        45.0  |
# |  AGGRESSIVE DR: VIOL CERTAIN OFF + HAZARD/HARASS    |        53.0  |
# |  GRAND LARCENY: FIREARM, NOT FROM A PERSON          |        31.0  |
# |  RECK DR: DR OUT OF CONTROL OR BAD BRAKES           |        29.0  |
# |  MOTEL/RESTAURANT/PARK/ETC: FRAUD <$200             |        65.0  |
# |  FIREARM: POSSESSION W/ SCH I OR II DRUG            |        30.5  |
# |  PASS CARRIER: TNC REGIST/ID MARKER REQ             |        37.0  |
# |  ANNOYING RINGING TO EMERG SERVICES/ FALSE RPT      |        45.0  |
# |  RECK DR: RACING                                    |        22.0  |
# |  IMPERSONATION: LAW ENFORCEMENT                     |        24.0  |
# |  WARRANT - TEMPORARY DETENTION ORDER                |        30.0  |
# |  ALCOHOL SAFETY PROGRAM VIOLATION                   |        37.0  |
# |  PROPOSE SEX BY COMP  <15 OFFENDR 7+ YR, 2ND OFF    |        34.5  |
# |  PROTECTIVE ORDER: 3ND VIOL W/IN 20YRS              |        60.0  |
# |  PROTECTIVE ORDER: 2ND VIOL W/IN 5 YRS              |        60.0  |
# |  BURGLARY: ENTER HOUSE TO MURDER/RAPE/ETC, ARMED    |        22.0  |
# |  TRESPASS: SCHOOL/CHURCH PROPERTY                   |        19.0  |
# |  DRUGS: INHALING DRUGS OR NOXIOUS CHEMICALS         |        23.0  |
# |  FIREARM: RECKLESS HANDLING                         |        34.0  |
# |  VEH WINDOWS: APPLY SUN-SHADING UNLAWFULLY, 1 OFF   |        26.0  |
# |  CARJACKING                                         |        30.0  |
# |  CREDIT CARD FRAUD: RECEIVE GOODS >=$200 IN 6M      |        23.5  |
# |  DWI: REFUSAL OF BLOOD OR BREATH TEST, 3 OFF        |        28.0  |
# |  DWI: 4+ OFF W/IN 10Y                               |        28.0  |
# |  DRUGS: SELL/PROVIDE FOR RESALE SCH I OR II         |        37.0  |
# |  FUGITIVE: ARREST ON FELONY CHARGE PER 19.2-99      |        39.0  |
# |  DRIVING AFTER FORFEITURE OF LICENSE:W/ BAC .02%+   |        46.0  |
# |  ACCIDENT: DRIVER NOT REPORT, PROPERTY DAMAG>$250   |        48.0  |
# |  TRESPASS, FIRST OFFENDER VIOLATION                 |        42.0  |
# |  GANG: PARTICIPATE IN CRIM ACT W/ JUV IN SCH ZONE   |        20.0  |
# |  FIREARM: SHOOT IN PUBLIC PLACE, NOT CAUSE INJURY   |        28.0  |
# |  ABDUCTION: BY PARENT, REMOVE FROM STATE            |        49.0  |
# |  RECKLESS DRIVING GENERALLY.                        |        20.0  |
# |  SCH ATTEND: NOT COMPLY W/ COMPULSORY ATTENDANCE    |        38.0  |
# |  DWI: 2ND OFF W/IN 5Y, BAC >.20%                    |        37.0  |
# |  LIC REVOKED: DR W/ SUSP/REV LIC, NO INSUR, 2+OFF   |        27.0  |
# |  ENTER A SCHOOL AFT CONVICTED OF SEX OFFENSE        |        55.0  |
# |  DRIVING AFTER FORFEITURE OF LICENSE                |        28.0  |
# |  OBSCENE MATERIAL: PRODUCE/POSSESS FOR SALE,2+OFF   |        44.0  |
# |  <15Y TO PERFORM PORN, OFFENDR 7+ YRS OLDER, 2ND    |        44.0  |
# |  PAROLE VIOLATION-FELONY                            |        25.0  |
# |  RECK DR: NOT STOP FOR SCH BUS + REV LIC & DEATH    |        43.0  |
# |  TITLE: POSSESS TITLE ISSUED TO ANOTHER             |        26.0  |
# |  DOG: FAIL TO CONTROL/RESULTS IN SERIOUS INJURY     |        49.0  |
# |  FALSE STATEMENTS: HOUSING AID                      |        24.0  |
# |  ACCIDENT: DRIVER NOT RPT, W/DEATH/INJURY           |        18.0  |
# |  LARCENY - SHOPLIFTING                              |        20.0  |
# |  LAW ENF COMMAND: DISREGARD OR ELUDE, ENDANGER      |        30.0  |
# |  TITLE/SALVAGE: OBTAIN/CREATE FALSE DOCS, FRAUD     |        43.0  |
# |-----------------------------------------------------+--------------|

# %%
import agate
arrests = agate.Table.from_csv('arrest.csv')

# %%
missing = arrests.where(lambda row:['Charge Descrip'] is None)

# %%
print len ('None')
# Out:
# 4
